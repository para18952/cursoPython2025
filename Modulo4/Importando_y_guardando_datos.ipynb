# %% [markdown]
# <a href="https://colab.research.google.com/github/ednavivianasegura/ERAP_CursoPython/blob/main/Modulo4/Importando_y_guardando_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
#                                               Procesamiento de datos con Pandas.

# %%
# !git clone https://github.com/ednavivianasegura/ERAP_CursoPython/Modulo4.git
# Out:
# Cloning into 'Modulo4'...
# remote: Not Found
# fatal: repository 'https://github.com/ednavivianasegura/ERAP_CursoPython/Modulo4.git/' not found

# %%
## Importando la librería
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %% [markdown]
# Importando archivos CSV

# %%
## Cargando datos como un objeto de pandas "dataframe"
landtemps = pd.read_csv('data/landtempssample.csv') # <- importamos el archivo de datos .csv
type(landtemps)                                     # <- Muestra que los datos estan cargados como un dataframe.
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# # Leer un archivo en formato zip
# landtemps = pd.read_csv('data/landtemps.zip',compression='zip',
#                         names=['stationid','year','month','avgtemp','latitude','longitude','elevation','station','countryid','country'],
#                         skiprows=1,
#                         low_memory=False)

# %%
## Observar la estructura de los datos
landtemps.shape   # <- Tipo de datos de cada columna.
#landtemps.dtypes # <- Tipo de datos de cada columna.
#landtemps.info()
# Out:
# (100000, 10)

# %%
## Imprimir el “dataframe”.
landtemps
# Out:
#         locationid  year  month   temp  latitude  longitude  stnelev  \
# 0      USS0010K01S  2000      4   5.27   39.9000  -110.7500   2773.7
# 1      CI000085406  1940      5  18.04  -18.3500   -70.3330     58.0
# 2      USC00036376  2013     12   6.22   34.3703   -91.1242     61.0
# 3      ASN00024002  1963      2  22.93  -34.2833   140.6000     65.5
# 4      ASN00028007  2001     11    NaN  -14.7803   143.5036     79.4
# ...            ...   ...    ...    ...       ...        ...      ...
# 99995  MXXLT347415  1991      4  29.02   17.7800   -96.3100     65.0
# 99996  RSM00032287  1991     11  -2.81   57.0800   156.7000      3.0
# 99997  ARM00087166  1937      4  19.42  -27.4460   -58.7620     61.9
# 99998  CA006137361  1958     10  10.02   42.7833   -81.1667    236.0
# 99999  CA006137361  1966      1  -7.85   42.7833   -81.1667    236.0
#
#                     station countryid        country
# 0             INDIAN_CANYON        US  United States
# 1                     ARICA        CI          Chile
# 2             SAINT_CHARLES        US  United States
# 3          BERRI_IRRIGATION        AS      Australia
# 4                  MUSGRAVE        AS      Australia
# ...                     ...       ...            ...
# 99995  VALLE_NACIONAL_VALLE        MX         Mexico
# 99996        UST_HAIRYUZOVO        RS         Russia
# 99997            CORRIENTES        AR      Argentina
# 99998             ST_THOMAS        CA         Canada
# 99999             ST_THOMAS        CA         Canada
#
# [100000 rows x 10 columns]

# %%
# Ajustamos los parámetros para la visualización de los datos
pd.options.display.float_format = '{:,.2f}'.format
#pd.reset_option('display.float_format')            # <- Quita el formato de floats
#landtemps.columns                                  # <- Nombre de cada columna
#len(landtemps.columns)                             # <- Número de columnas
#pd.set_option('display.width', 200)                # <- Ancho de cada columna
#pd.reset_option('display.width')                   # <- Vuelve al ancho automático
pd.set_option('display.max_columns', 10)            # <- Número máximo de columnas a mostrar
landtemps
# Out:
#         locationid  year  month  temp  latitude  longitude  stnelev  \
# 0      USS0010K01S  2000      4  5.27     39.90    -110.75 2,773.70
# 1      CI000085406  1940      5 18.04    -18.35     -70.33    58.00
# 2      USC00036376  2013     12  6.22     34.37     -91.12    61.00
# 3      ASN00024002  1963      2 22.93    -34.28     140.60    65.50
# 4      ASN00028007  2001     11   NaN    -14.78     143.50    79.40
# ...            ...   ...    ...   ...       ...        ...      ...
# 99995  MXXLT347415  1991      4 29.02     17.78     -96.31    65.00
# 99996  RSM00032287  1991     11 -2.81     57.08     156.70     3.00
# 99997  ARM00087166  1937      4 19.42    -27.45     -58.76    61.90
# 99998  CA006137361  1958     10 10.02     42.78     -81.17   236.00
# 99999  CA006137361  1966      1 -7.85     42.78     -81.17   236.00
#
#                     station countryid        country
# 0             INDIAN_CANYON        US  United States
# 1                     ARICA        CI          Chile
# 2             SAINT_CHARLES        US  United States
# 3          BERRI_IRRIGATION        AS      Australia
# 4                  MUSGRAVE        AS      Australia
# ...                     ...       ...            ...
# 99995  VALLE_NACIONAL_VALLE        MX         Mexico
# 99996        UST_HAIRYUZOVO        RS         Russia
# 99997            CORRIENTES        AR      Argentina
# 99998             ST_THOMAS        CA         Canada
# 99999             ST_THOMAS        CA         Canada
#
# [100000 rows x 10 columns]

# %%
## Etiquetar  las columnas al importar los datos.

# Vamos a cambiar los nombres de las columnas al importar los datos.
landtemps= pd.read_csv("data/landtempssample.csv",
                      names=["Id_estacion", "año", "mes", "temperatura_promedio", "latitud", "longitud","elevacion", "estacion","Id_pais","pais"],
                      skiprows=1 # <- Necesitamos que se salte la primera linea, donde están los títulos
                      )
landtemps
# Out:
#        Id_estacion   año  mes  temperatura_promedio  latitud  longitud  \
# 0      USS0010K01S  2000    4                  5.27    39.90   -110.75
# 1      CI000085406  1940    5                 18.04   -18.35    -70.33
# 2      USC00036376  2013   12                  6.22    34.37    -91.12
# 3      ASN00024002  1963    2                 22.93   -34.28    140.60
# 4      ASN00028007  2001   11                   NaN   -14.78    143.50
# ...            ...   ...  ...                   ...      ...       ...
# 99995  MXXLT347415  1991    4                 29.02    17.78    -96.31
# 99996  RSM00032287  1991   11                 -2.81    57.08    156.70
# 99997  ARM00087166  1937    4                 19.42   -27.45    -58.76
# 99998  CA006137361  1958   10                 10.02    42.78    -81.17
# 99999  CA006137361  1966    1                 -7.85    42.78    -81.17
#
#        elevacion              estacion Id_pais           pais
# 0       2,773.70         INDIAN_CANYON      US  United States
# 1          58.00                 ARICA      CI          Chile
# 2          61.00         SAINT_CHARLES      US  United States
# 3          65.50      BERRI_IRRIGATION      AS      Australia
# 4          79.40              MUSGRAVE      AS      Australia
# ...          ...                   ...     ...            ...
# 99995      65.00  VALLE_NACIONAL_VALLE      MX         Mexico
# 99996       3.00        UST_HAIRYUZOVO      RS         Russia
# 99997      61.90            CORRIENTES      AR      Argentina
# 99998     236.00             ST_THOMAS      CA         Canada
# 99999     236.00             ST_THOMAS      CA         Canada
#
# [100000 rows x 10 columns]

# %%
# imprimir columnas específicas
columnas_seleccionadas=['Id_estacion', 'año','mes','pais']
landtemps[columnas_seleccionadas].head(3)  # <- Además de indicar que columnas se imprimen, también se indica cuantas filas.
# Out:
#    Id_estacion   año  mes           pais
# 0  USS0010K01S  2000    4  United States
# 1  CI000085406  1940    5          Chile
# 2  USC00036376  2013   12  United States

# %% [raw]
# Navegación en los “dataframes”.

# %% [raw]
# .iloc → Selección por posición numérica
#
#    Qué usa: Índices numéricos basados en la posición (0, 1, 2...), ignora las etiquetas.
#
#    Sintaxis: df.iloc[fila_inicio:fila_fin, columna_inicio:columna_fin]
#
#    Características clave:
#
#    Exclusivo: iloc excluye el último elemento del rango (como en Python estándar, ej: 0:2 incluye posiciones 0 y 1).
#
#    Útil para programación genérica: Cuando no conoces los nombres de las etiquetas.
#
#    EJEMPLO:
#
#     # Seleccionar la fila 1  y columna 0 :
#     df.iloc[1, 0]  # → 450
#
#     # Rango de filas 0 a 1 (excluye 2) y todas las columnas:
#     df.iloc[0:2, :]
#
#     Bonus:
#
#     # Esto sí funciona (usa iloc para posiciones):
#     df.iloc[0, df.columns.get_loc('GDP')]  # Primera fila, columna 'GDP'. Indica la posición de esa columna

# %%
# Selección por posición numérica
# Ejemplo
#landtemps.iloc[filas,columnas]
#landtemps.iloc[fila_inicio:fila_fin, columna_inicio:columna_fin]
landtemps.iloc[0:5, 0:10]
#landtemps.iloc[[1,4,5],[0,2,4]]
# Out:
#    Id_estacion   año  mes  temperatura_promedio  latitud  longitud  elevacion  \
# 0  USS0010K01S  2000    4                  5.27    39.90   -110.75   2,773.70
# 1  CI000085406  1940    5                 18.04   -18.35    -70.33      58.00
# 2  USC00036376  2013   12                  6.22    34.37    -91.12      61.00
# 3  ASN00024002  1963    2                 22.93   -34.28    140.60      65.50
# 4  ASN00028007  2001   11                   NaN   -14.78    143.50      79.40
#
#            estacion Id_pais           pais
# 0     INDIAN_CANYON      US  United States
# 1             ARICA      CI          Chile
# 2     SAINT_CHARLES      US  United States
# 3  BERRI_IRRIGATION      AS      Australia
# 4          MUSGRAVE      AS      Australia

# %% [raw]
# .loc → Selección por etiquetas de índice (labels) o por indexación booleana.
#
#     Qué usa: Índices de filas y nombres de columnas como se ven en el DataFrame (etiquetas).
#
#     Funciona con los nombres reales del índice o columnas (ej: 'elevacion', 'estacion').
#
#     Sintaxis: landtemps.loc[fila_inicio:fila_fin, columna_inicio:columna_fin]
#
#     Características clave:
#
#         Inclusivo: loc incluye el último elemento del rango (ej: 'A':'C' incluye 'A', 'B' y 'C').
#
#         Acepta booleanos: Puedes usar condiciones (ej: df.loc[df['temperatura_promedio'] > 500]).
#
#     Ejemplo:
#             # Seleccionar fila 'París' y columna 'GDP':
#                 df.loc['París', 'GDP']  # → 450
#
#             # Rango de filas (incluye 'Tokio') y todas las columnas:
#                 df.loc['Nueva York':'Tokio', :]

# %%
# Selección por etiquetas (labels)
# Se va a reducir la base para mejorar la visualización y para evitar valores repetidos
base_landtemps_reducida= landtemps.iloc[0:5,:].copy()

# %%
base_landtemps_reducida
# Out:
#    Id_estacion   año  mes  temperatura_promedio  latitud  longitud  elevacion  \
# 0  USS0010K01S  2000    4                  5.27    39.90   -110.75   2,773.70
# 1  CI000085406  1940    5                 18.04   -18.35    -70.33      58.00
# 2  USC00036376  2013   12                  6.22    34.37    -91.12      61.00
# 3  ASN00024002  1963    2                 22.93   -34.28    140.60      65.50
# 4  ASN00028007  2001   11                   NaN   -14.78    143.50      79.40
#
#            estacion Id_pais           pais
# 0     INDIAN_CANYON      US  United States
# 1             ARICA      CI          Chile
# 2     SAINT_CHARLES      US  United States
# 3  BERRI_IRRIGATION      AS      Australia
# 4          MUSGRAVE      AS      Australia

# %%
# Se necesita primero indicar quien va a ser el indice para recorrer por filas
base_landtemps_reducida.\
set_index('Id_estacion', inplace=True) # <- Reemplaza el índice automático numérico predeterminado (0, 1, 2...) por
                                       # <- los valores únicos de la columna 'Id_estacion'. Estos pasarán a ser
                                       # <- las etiquetas de las filas.

# %%
# Ejemplo
base_landtemps_reducida.loc['USS0010K01S':'ASN00024002', 'latitud':'estacion'] # <- Seleccionar filas y columnas en particular
# Out:
#              latitud  longitud  elevacion          estacion
# Id_estacion
# USS0010K01S    39.90   -110.75   2,773.70     INDIAN_CANYON
# CI000085406   -18.35    -70.33      58.00             ARICA
# USC00036376    34.37    -91.12      61.00     SAINT_CHARLES
# ASN00024002   -34.28    140.60      65.50  BERRI_IRRIGATION

# %%
base_landtemps_reducida
# Out:
#               año  mes  temperatura_promedio  latitud  longitud  elevacion  \
# Id_estacion
# USS0010K01S  2000    4                  5.27    39.90   -110.75   2,773.70
# CI000085406  1940    5                 18.04   -18.35    -70.33      58.00
# USC00036376  2013   12                  6.22    34.37    -91.12      61.00
# ASN00024002  1963    2                 22.93   -34.28    140.60      65.50
# ASN00028007  2001   11                   NaN   -14.78    143.50      79.40
#
#                      estacion Id_pais           pais
# Id_estacion
# USS0010K01S     INDIAN_CANYON      US  United States
# CI000085406             ARICA      CI          Chile
# USC00036376     SAINT_CHARLES      US  United States
# ASN00024002  BERRI_IRRIGATION      AS      Australia
# ASN00028007          MUSGRAVE      AS      Australia

# %%
# Seleccionando a partir de condiciones lógicas.
mostrar=[base_landtemps_reducida['temperatura_promedio']>6.5]# <- aquí se seleccionan los valores que cumplen la condición
#mostrar
base_landtemps_reducida['temperatura_promedio'][mostrar[0]]  # <- aquí se muestran esos valores
# Out:
# Id_estacion
# CI000085406   18.04
# ASN00024002   22.93
# Name: temperatura_promedio, dtype: float64

# %%
# Para observar las filas con NaN
base_landtemps_reducida.isna().sum()
# Out:
# año                     0
# mes                     0
# temperatura_promedio    1
# latitud                 0
# longitud                0
# elevacion               0
# estacion                0
# Id_pais                 0
# pais                    0
# dtype: int64

# %% [raw]
# ########### Abro paréntesis, observemos la base inicial y contemos cuántos valores perdidos existen #######

# %%
# Por ejemplo, solo en la columna: Id_estacion
landtemps['Id_estacion'].nunique() # <- Cuántos valores son únicos
#len(landtemps['Id_estacion'])
# Out:
# 24528

# %%
# Observemos que filas tienen al menos 1 NaN

filas_con_nan = landtemps[landtemps.isna().any(axis=1)] # <- Filtrar filas con al menos un NaN
#print(f"Filas con valores NaN:\n{filas_con_nan.iloc[0:10,2:4]}")
filas_con_nan
# Out:
#        Id_estacion   año  mes  temperatura_promedio  latitud  longitud  \
# 4      ASN00028007  2001   11                   NaN   -14.78    143.50
# 11     USC00303319  2000    9                   NaN    43.05    -74.36
# 12     IN001111200  1941   12                   NaN    16.20     81.15
# 13     USC00143759  2020    9                   NaN    39.46    -95.75
# 24     USC00324571  1972    6                   NaN    47.90   -102.92
# ...            ...   ...  ...                   ...      ...       ...
# 99962  SFM00068242  1964    8                   NaN   -25.80     25.55
# 99965  USC00029420  1974    8                   NaN    32.92   -110.72
# 99974  MXXLT223734  1989    5                   NaN    23.21   -110.03
# 99980  USC00425402  1911   11                   NaN    39.26   -111.63
# 99982  CA008403401  1970    6                   NaN    51.37    -55.60
#
#        elevacion              estacion Id_pais           pais
# 4          79.40              MUSGRAVE      AS      Australia
# 11        246.90          GLOVERSVILLE      US  United States
# 12          3.00         MACHILIPATNAM      IN          India
# 13        320.60                HOLTON      US  United States
# 24        752.90              KEENE_3S      US  United States
# ...          ...                   ...     ...            ...
# 99962   1,274.40              MAFIKENG      SF   South Africa
# 99965     634.00         WINKELMAN_6_S      US  United States
# 99974      80.00  SAN_JACINTOTODOS_SAN      MX         Mexico
# 99980   1,749.60                 MANTI      US  United States
# 99982      12.00            ST_ANTHONY      CA         Canada
#
# [14448 rows x 10 columns]

# %%
# Para contar valores únicos y duplicados en cada columna
for col in landtemps.columns:                               # <- Recorremos todas las columnas
    unique_count = landtemps[col].nunique()                 # <- Guardammos en una variable el número de valores unicos
    total_count = len(landtemps[col])                       # <- Guardammos en una variable el número total de valores
    duplicate_count = total_count - unique_count            # <- Calculamos el numero de valores duplicados
    print(f"Columna '{col}': {duplicate_count} valores duplicados ({unique_count} valores únicos)") # Imprimimos el resultado
# Out:
# Columna 'Id_estacion': 75472 valores duplicados (24528 valores únicos)
# Columna 'año': 99730 valores duplicados (270 valores únicos)
# Columna 'mes': 99988 valores duplicados (12 valores únicos)
# Columna 'temperatura_promedio': 93974 valores duplicados (6026 valores únicos)
# Columna 'latitud': 83890 valores duplicados (16110 valores únicos)
# Columna 'longitud': 80767 valores duplicados (19233 valores únicos)
# Columna 'elevacion': 94576 valores duplicados (5424 valores únicos)
# Columna 'estacion': 76833 valores duplicados (23167 valores únicos)
# Columna 'Id_pais': 99763 valores duplicados (237 valores únicos)
# Columna 'pais': 99764 valores duplicados (236 valores únicos)

# %%
# Para encontrar filas completamente duplicadas
landtemps.duplicated(keep=False)

##Comportamiento según el parámetro keep:
##keep='first' (valor por defecto) Marca como True todas las ocurrencias duplicadas excepto la primera Útil cuando quieres conservar la primera aparición y eliminar las copias
##keep='last' Marca como True todas las ocurrencias duplicadas excepto la última Útil cuando quieres conservar la última aparición
## keep=False Marca como True todas las ocurrencias duplicadas (incluyendo la primera y última) Útil cuando quieres identificar todos los elementos que tienen duplicados

duplicados_completos = landtemps[landtemps.duplicated(keep=False)]
print(f"\nFilas completamente duplicadas: {len(duplicados_completos)}")
# Out:
# Filas completamente duplicadas: 0

# %%
# Existe un problema si se tienen filas duplicadas, en el caso de la selección usando .loc
AAA=landtemps.set_index('Id_estacion', inplace=False)

# %% [raw]
# #AAA.loc['USS0010K01S':'ASN00024002', 'latitud':'estacion'] # Error -> non-unique label

# %%
# Si se quisiera eliminar todas las filas con duplicados.
AAA = landtemps.drop_duplicates(subset=['mes'], keep='first')
AAA
# Out:
#     Id_estacion   año  mes  temperatura_promedio  latitud  longitud  \
# 0   USS0010K01S  2000    4                  5.27    39.90   -110.75
# 1   CI000085406  1940    5                 18.04   -18.35    -70.33
# 2   USC00036376  2013   12                  6.22    34.37    -91.12
# 3   ASN00024002  1963    2                 22.93   -34.28    140.60
# 4   ASN00028007  2001   11                   NaN   -14.78    143.50
# 7   USC00470307  1943    1                -10.43    43.33    -89.37
# 8   FRM00007579  1996    8                 21.87    44.13      4.83
# 11  USC00303319  2000    9                   NaN    43.05    -74.36
# 15  USC00471708  1978   10                  6.85    44.37    -89.53
# 19  ROM00015280  1955    6                  2.66    45.45     25.45
# 26  USC00356466  2010    7                 17.61    45.53   -121.59
# 28  USC00346638  1960    3                  4.63    35.43    -96.30
#
#     elevacion          estacion Id_pais           pais
# 0    2,773.70     INDIAN_CANYON      US  United States
# 1       58.00             ARICA      CI          Chile
# 2       61.00     SAINT_CHARLES      US  United States
# 3       65.50  BERRI_IRRIGATION      AS      Australia
# 4       79.40          MUSGRAVE      AS      Australia
# 7      317.00         ARLINGTON      US  United States
# 8       55.00            ORANGE      FR         France
# 11     246.90      GLOVERSVILLE      US  United States
# 15     323.10    CODDINGTON_1_E      US  United States
# 19   2,504.00        VARFU_OMUL      RO        Romania
# 26     463.30    PARKDALE_1_NNE      US  United States
# 28     285.00            OKEMAH      US  United States

# %% [raw]
# ########### Cierro paréntesis #######

# %% [raw]
# Seleccionando filas y columnas a partír de múltiples condiciones

# %%
base_landtemps_reducida
# Out:
#               año  mes  temperatura_promedio  latitud  longitud  elevacion  \
# Id_estacion
# USS0010K01S  2000    4                  5.27    39.90   -110.75   2,773.70
# CI000085406  1940    5                 18.04   -18.35    -70.33      58.00
# USC00036376  2013   12                  6.22    34.37    -91.12      61.00
# ASN00024002  1963    2                 22.93   -34.28    140.60      65.50
# ASN00028007  2001   11                   NaN   -14.78    143.50      79.40
#
#                      estacion Id_pais           pais
# Id_estacion
# USS0010K01S     INDIAN_CANYON      US  United States
# CI000085406             ARICA      CI          Chile
# USC00036376     SAINT_CHARLES      US  United States
# ASN00024002  BERRI_IRRIGATION      AS      Australia
# ASN00028007          MUSGRAVE      AS      Australia

# %%
# Aquí seleccionamos la condición por fila e indicamos las columnas que se quieren mostrar
columnas_a_mostrar= base_landtemps_reducida.columns
base_landtemps_reducida.loc[(base_landtemps_reducida.longitud<=0)\
& (base_landtemps_reducida.elevacion>=58), [columnas_a_mostrar][0][[1,2,5]]]
# Out:
#              mes  temperatura_promedio  elevacion
# Id_estacion
# USS0010K01S    4                  5.27   2,773.70
# CI000085406    5                 18.04      58.00
# USC00036376   12                  6.22      61.00

# %% [raw]
# Combinando y renombrando columnas.
# Se va a unir mes y año

# %%
# Combinar 'year' y 'month' en una columna de fecha
base_landtemps_reducida['mes-año'] = pd.to_datetime(
    base_landtemps_reducida['año'].astype(str) + '-' + base_landtemps_reducida['mes'].astype(str),
    format='%Y-%m'  # formato año mes
)
base_landtemps_reducida
# Out:
#               año  mes  temperatura_promedio  latitud  longitud  elevacion  \
# Id_estacion
# USS0010K01S  2000    4                  5.27    39.90   -110.75   2,773.70
# CI000085406  1940    5                 18.04   -18.35    -70.33      58.00
# USC00036376  2013   12                  6.22    34.37    -91.12      61.00
# ASN00024002  1963    2                 22.93   -34.28    140.60      65.50
# ASN00028007  2001   11                   NaN   -14.78    143.50      79.40
#
#                      estacion Id_pais           pais    mes-año
# Id_estacion
# USS0010K01S     INDIAN_CANYON      US  United States 2000-04-01
# CI000085406             ARICA      CI          Chile 1940-05-01
# USC00036376     SAINT_CHARLES      US  United States 2013-12-01
# ASN00024002  BERRI_IRRIGATION      AS      Australia 1963-02-01
# ASN00028007          MUSGRAVE      AS      Australia 2001-11-01

# %%
# Arreglar el error (mes-año) y cambiar el nombre de la columna
base_landtemps_reducida.rename(columns={'mes-año':'año-mes'}, inplace=True)
base_landtemps_reducida
# Out:
#               año  mes  temperatura_promedio  latitud  longitud  elevacion  \
# Id_estacion
# USS0010K01S  2000    4                  5.27    39.90   -110.75   2,773.70
# CI000085406  1940    5                 18.04   -18.35    -70.33      58.00
# USC00036376  2013   12                  6.22    34.37    -91.12      61.00
# ASN00024002  1963    2                 22.93   -34.28    140.60      65.50
# ASN00028007  2001   11                   NaN   -14.78    143.50      79.40
#
#                      estacion Id_pais           pais    año-mes
# Id_estacion
# USS0010K01S     INDIAN_CANYON      US  United States 2000-04-01
# CI000085406             ARICA      CI          Chile 1940-05-01
# USC00036376     SAINT_CHARLES      US  United States 2013-12-01
# ASN00024002  BERRI_IRRIGATION      AS      Australia 1963-02-01
# ASN00028007          MUSGRAVE      AS      Australia 2001-11-01

# %%
# Eliminar columnas en particular en el mismo DataFrame (sin crear uno nuevo)
base_landtemps_reducida.drop(columns=['año','mes'], inplace=True) # <- Si se omite inplace=True, el DataFrame original no se modifica.
# columna_eliminada = landtemps.pop('month')  # Elimina 'month' y guarda sus datos
# del landtemps['month']  # Elimina la columna 'month' directamente, solo puede eliminar una columna a la vez
base_landtemps_reducida
# Out:
#              temperatura_promedio  latitud  longitud  elevacion  \
# Id_estacion
# USS0010K01S                  5.27    39.90   -110.75   2,773.70
# CI000085406                 18.04   -18.35    -70.33      58.00
# USC00036376                  6.22    34.37    -91.12      61.00
# ASN00024002                 22.93   -34.28    140.60      65.50
# ASN00028007                   NaN   -14.78    143.50      79.40
#
#                      estacion Id_pais           pais    año-mes
# Id_estacion
# USS0010K01S     INDIAN_CANYON      US  United States 2000-04-01
# CI000085406             ARICA      CI          Chile 1940-05-01
# USC00036376     SAINT_CHARLES      US  United States 2013-12-01
# ASN00024002  BERRI_IRRIGATION      AS      Australia 1963-02-01
# ASN00028007          MUSGRAVE      AS      Australia 2001-11-01

# %%
# Vamos a definir un orden personalizado para el DataFrame
#landtemps.columns
orden_personalizado = ['año-mes','latitud', 'longitud', 'elevacion','estacion', 'Id_pais', 'pais']
base_landtemps_reducida=base_landtemps_reducida[orden_personalizado]
# Para mostrar en orden alfabético:
# landtemps = landtemps.sort_index(axis=1)  # axis=1 indica columnas
base_landtemps_reducida
# Out:
#                año-mes  latitud  longitud  elevacion          estacion  \
# Id_estacion
# USS0010K01S 2000-04-01    39.90   -110.75   2,773.70     INDIAN_CANYON
# CI000085406 1940-05-01   -18.35    -70.33      58.00             ARICA
# USC00036376 2013-12-01    34.37    -91.12      61.00     SAINT_CHARLES
# ASN00024002 1963-02-01   -34.28    140.60      65.50  BERRI_IRRIGATION
# ASN00028007 2001-11-01   -14.78    143.50      79.40          MUSGRAVE
#
#             Id_pais           pais
# Id_estacion
# USS0010K01S      US  United States
# CI000085406      CI          Chile
# USC00036376      US  United States
# ASN00024002      AS      Australia
# ASN00028007      AS      Australia

# %% [markdown]
#                                                 Importar datos guardados usando Excel.
#
# Consideraciones:
# 1. A pesar de la estructura tabular de Excel, que invita a organizar los datos en filas y columnas,
#    las hojas de cálculo no son conjuntos de datos y no exigen que la gente almacene los datos de esa manera.
#
# 2. Suele haber información adicional en filas o columnas antes o después de los datos que hay que importar.
#
# 3. Los tipos de datos no siempre están tan claros como para la persona que creó la hoja de cálculo.
#
# 4. Excel no insiste en que todos los datos de una columna sean del mismo tipo, o que los títulos de las columnas sean apropiados para su
#    uso con un lenguaje de programación como Python.
#
# Manejo:
#
# "read_excel" tiene una serie de opciones para manejar la confusión en los datos de Excel. Como omitir filas, seleccionar columnas
#              concretas y extraer datos de una hoja u hojas determinadas.

# %%
percapitaGDP = pd.read_excel("data/GDPpercapita22b.xlsx",sheet_name="OECD.Stat export",skiprows=4,skipfooter=1,usecols="A,C:W")
#pd.set_option('display.max_columns', 10)
#pd.reset_option('display.max_columns')
#percapitaGDP.columns
#columnas_seleccionadas=['2001', '2002','2003']
#percapitaGDP[columnas_seleccionadas].head()
percapitaGDP.head()
# Out:
#                          Year 2000   2001   2002   2003  ...   2016   2017  \
# 0          Metropolitan areas  NaN    NaN    NaN    NaN  ...    NaN    NaN
# 1              AUS: Australia   ..     ..     ..     ..  ...     ..     ..
# 2       AUS01: Greater Sydney   ..  41091  41781  42988  ...  47582  47569
# 3    AUS02: Greater Melbourne   ..  40488  41136  42164  ...  43394  43772
# 4     AUS03: Greater Brisbane   ..  35276  35676  37092  ...  43547  44663
#
#     2018   2019   2020
# 0    NaN    NaN    NaN
# 1     ..     ..     ..
# 2  47171  45576  45152
# 3  43237  42299  40848
# 4  44328  42145  40741
#
# [5 rows x 22 columns]

# %%
## Observar la estructura de los datos
#landtemps.shape
#landtemps.dtypes # <- Tipo de datos de cada columna.
percapitaGDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    731 non-null    object
#  1   2000    730 non-null    object
#  2   2001    730 non-null    object
#  3   2002    730 non-null    object
#  4   2003    730 non-null    object
#  5   2004    730 non-null    object
#  6   2005    730 non-null    object
#  7   2006    730 non-null    object
#  8   2007    730 non-null    object
#  9   2008    730 non-null    object
#  10  2009    730 non-null    object
#  11  2010    730 non-null    object
#  12  2011    730 non-null    object
#  13  2012    730 non-null    object
#  14  2013    730 non-null    object
#  15  2014    730 non-null    object
#  16  2015    730 non-null    object
#  17  2016    730 non-null    object
#  18  2017    730 non-null    object
#  19  2018    730 non-null    object
#  20  2019    730 non-null    object
#  21  2020    730 non-null    object
# dtypes: object(22)
# memory usage: 125.8+ KB

# %%
# ¿cuántos valores faltantes tiene la tabla?
percapitaGDP.isnull()         #<- verifica por filas si faltan datos false,true
#percapitaGDP.isnull().sum()   #<- suma por filas los datos faltantes (Obsérvese que no se tienen en cuenta las celdas con ...)
# Out:
#       Year   2000   2001   2002   2003  ...   2016   2017   2018   2019   2020
# 0    False   True   True   True   True  ...   True   True   True   True   True
# 1    False  False  False  False  False  ...  False  False  False  False  False
# 2    False  False  False  False  False  ...  False  False  False  False  False
# 3    False  False  False  False  False  ...  False  False  False  False  False
# 4    False  False  False  False  False  ...  False  False  False  False  False
# ..     ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 726  False  False  False  False  False  ...  False  False  False  False  False
# 727  False  False  False  False  False  ...  False  False  False  False  False
# 728  False  False  False  False  False  ...  False  False  False  False  False
# 729  False  False  False  False  False  ...  False  False  False  False  False
# 730  False  False  False  False  False  ...  False  False  False  False  False
#
# [731 rows x 22 columns]

# %%
#mostrar=[percapitaGDP["2000"].isnull()] # <- aquí se seleccionan los valores que cumplen la condición
#mostrar
#percapitaGDP["2000"][mostrar[0]].index

# %%
# Vamos a renombrar la primera columna
percapitaGDP.rename(columns={'Year':'metro'}, inplace=True)
percapitaGDP
# Out:
#                           metro 2000   2001   2002   2003  ...   2016   2017  \
# 0            Metropolitan areas  NaN    NaN    NaN    NaN  ...    NaN    NaN
# 1                AUS: Australia   ..     ..     ..     ..  ...     ..     ..
# 2         AUS01: Greater Sydney   ..  41091  41781  42988  ...  47582  47569
# 3      AUS02: Greater Melbourne   ..  40488  41136  42164  ...  43394  43772
# 4       AUS03: Greater Brisbane   ..  35276  35676  37092  ...  43547  44663
# ..                          ...  ...    ...    ...    ...  ...    ...    ...
# 726               USA158: Butte   ..  31067  32560  33669  ...  37570  38534
# 727              USA160: Yakima   ..  29554  30549  31701  ...  37706  38410
# 728              USA161: Brazos   ..  34780  35138  38281  ...  45336  47559
# 729          USA162: Tuscaloosa   ..  35620  36963  40295  ...  41260  43149
# 730         USA170: Benton (AR)   ..  42699  45577  45958  ...  49784  51043
#
#       2018   2019   2020
# 0      NaN    NaN    NaN
# 1       ..     ..     ..
# 2    47171  45576  45152
# 3    43237  42299  40848
# 4    44328  42145  40741
# ..     ...    ...    ...
# 726  39029  41680  41317
# 727  39815  40211  40104
# 728  49483  49113  45939
# 729  43973  45120  42095
# 730  51328  51739  51423
#
# [731 rows x 22 columns]

# %%
# Vamos a eliminar los espacios en blanco de la primera columna
percapitaGDP.metro.str.startswith(' ').any() # <- preguntamos primero si hay algún espacio en blanco antes del nombre
# Out:
# np.True_

# %%
percapitaGDP.metro.str.endswith(' ').any() # <- preguntamos segundo si hay algún espacio en blanco despúes del nombre
# Out:
# np.False_

# %%
percapitaGDP.metro = percapitaGDP.metro.str.strip() # <- con esto se remueven los espacios en blanco antes y despúes del texto

# %%
percapitaGDP
# Out:
#                         metro 2000   2001   2002   2003  ...   2016   2017  \
# 0          Metropolitan areas  NaN    NaN    NaN    NaN  ...    NaN    NaN
# 1              AUS: Australia   ..     ..     ..     ..  ...     ..     ..
# 2       AUS01: Greater Sydney   ..  41091  41781  42988  ...  47582  47569
# 3    AUS02: Greater Melbourne   ..  40488  41136  42164  ...  43394  43772
# 4     AUS03: Greater Brisbane   ..  35276  35676  37092  ...  43547  44663
# ..                        ...  ...    ...    ...    ...  ...    ...    ...
# 726             USA158: Butte   ..  31067  32560  33669  ...  37570  38534
# 727            USA160: Yakima   ..  29554  30549  31701  ...  37706  38410
# 728            USA161: Brazos   ..  34780  35138  38281  ...  45336  47559
# 729        USA162: Tuscaloosa   ..  35620  36963  40295  ...  41260  43149
# 730       USA170: Benton (AR)   ..  42699  45577  45958  ...  49784  51043
#
#       2018   2019   2020
# 0      NaN    NaN    NaN
# 1       ..     ..     ..
# 2    47171  45576  45152
# 3    43237  42299  40848
# 4    44328  42145  40741
# ..     ...    ...    ...
# 726  39029  41680  41317
# 727  39815  40211  40104
# 728  49483  49113  45939
# 729  43973  45120  42095
# 730  51328  51739  51423
#
# [731 rows x 22 columns]

# %% [raw]
# Convierta las columnas de datos en numéricas.
# convertir el tipo de datos de objeto a flotante (recuerde que al principio todo es type=object)
# use coerce, para que obligue a convertir las celdas con ... en número, lo que hace que se pase a tipo NaN

# %%
percapitaGDP.columns
# Out:
# Index(['metro', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
percapitaGDP.columns[1:]
# Out:
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020'],
#       dtype='object')

# %%
for col in percapitaGDP.columns[1:]:
    percapitaGDP[col] = pd.to_numeric(percapitaGDP[col], errors='coerce')
    percapitaGDP.rename(columns={col:'año-'+col[:]},inplace=True)

percapitaGDP.head()
# Out:
#                       metro  año-2000  año-2001  año-2002  año-2003  ...  \
# 0        Metropolitan areas       NaN       NaN       NaN       NaN  ...
# 1            AUS: Australia       NaN       NaN       NaN       NaN  ...
# 2     AUS01: Greater Sydney       NaN 41,091.00 41,781.00 42,988.00  ...
# 3  AUS02: Greater Melbourne       NaN 40,488.00 41,136.00 42,164.00  ...
# 4   AUS03: Greater Brisbane       NaN 35,276.00 35,676.00 37,092.00  ...
#
#    año-2016  año-2017  año-2018  año-2019  año-2020
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2 47,582.00 47,569.00 47,171.00 45,576.00 45,152.00
# 3 43,394.00 43,772.00 43,237.00 42,299.00 40,848.00
# 4 43,547.00 44,663.00 44,328.00 42,145.00 40,741.00
#
# [5 rows x 22 columns]

# %%
percapitaGDP.dtypes
# Out:
# metro        object
# año-2000    float64
# año-2001    float64
# año-2002    float64
# año-2003    float64
# año-2004    float64
# año-2005    float64
# año-2006    float64
# año-2007    float64
# año-2008    float64
# año-2009    float64
# año-2010    float64
# año-2011    float64
# año-2012    float64
# año-2013    float64
# año-2014    float64
# año-2015    float64
# año-2016    float64
# año-2017    float64
# año-2018    float64
# año-2019    float64
# año-2020    float64
# dtype: object

# %%
# Remover filas donde se tienen valores perdidos

# %%
percapitaGDP.dropna(subset=percapitaGDP.columns[1:], how="all", inplace=True)

# %%
percapitaGDP.shape
percapitaGDP.head(158)
# Out:
#                         metro  año-2000  año-2001  año-2002  año-2003  ...  \
# 2       AUS01: Greater Sydney       NaN 41,091.00 41,781.00 42,988.00  ...
# 3    AUS02: Greater Melbourne       NaN 40,488.00 41,136.00 42,164.00  ...
# 4     AUS03: Greater Brisbane       NaN 35,276.00 35,676.00 37,092.00  ...
# 5        AUS04: Greater Perth       NaN 43,355.00 44,849.00 46,475.00  ...
# 6     AUS05: Greater Adelaide       NaN 36,081.00 36,928.00 37,491.00  ...
# ..                        ...       ...       ...       ...       ...  ...
# 165            DK004: Aalborg       NaN       NaN       NaN       NaN  ...
# 167             ES001: Madrid       NaN       NaN       NaN 44,028.00  ...
# 168          ES002: Barcelona       NaN       NaN       NaN 39,047.00  ...
# 169           ES003: Valencia       NaN       NaN       NaN 31,613.00  ...
# 170            ES004: Seville       NaN       NaN       NaN 26,917.00  ...
#
#      año-2016  año-2017  año-2018  año-2019  año-2020
# 2   47,582.00 47,569.00 47,171.00 45,576.00 45,152.00
# 3   43,394.00 43,772.00 43,237.00 42,299.00 40,848.00
# 4   43,547.00 44,663.00 44,328.00 42,145.00 40,741.00
# 5   62,433.00 62,686.00 67,313.00 70,970.00 78,489.00
# 6   38,984.00 39,302.00 39,055.00 38,314.00 39,181.00
# ..        ...       ...       ...       ...       ...
# 165 41,533.00 42,528.00 42,385.00 42,755.00 41,557.00
# 167 48,186.00 49,550.00 50,246.00 51,020.00       NaN
# 168 42,236.00 43,585.00 44,408.00 45,016.00       NaN
# 169 31,851.00 32,368.00 33,283.00 33,570.00       NaN
# 170 28,251.00 29,098.00 29,663.00 30,004.00       NaN
#
# [158 rows x 22 columns]

# %%
percapitaGDP.metro.count()
# Out:
# np.int64(692)

# %%
percapitaGDP.metro.nunique()
# Out:
# 692

# %% [raw]
# INICIO DE LA ACTIVIDAD EN CLASE

# %%
# Devuelve la fila de AUS01: Greater Sydney. (Tarea)
# Out:
# metro       AUS03: Greater Brisbane
# año-2000                        NaN
# año-2001                    35276.0
# año-2002                    35676.0
# año-2003                    37092.0
# año-2004                    38655.0
# año-2005                    40712.0
# año-2006                    42088.0
# año-2007                    42222.0
# año-2008                    43703.0
# año-2009                    41315.0
# año-2010                    40653.0
# año-2011                    42083.0
# año-2012                    41763.0
# año-2013                    41446.0
# año-2014                    41733.0
# año-2015                    42294.0
# año-2016                    43547.0
# año-2017                    44663.0
# año-2018                    44328.0
# año-2019                    42145.0
# año-2020                    40741.0
# Name: 4, dtype: object

# %%
percapitaGDP.set_index('metro', inplace=True) # <- Reemplaza el índice automático numérico predeterminado (0, 1, 2...) por
                                              # <- los valores únicos de la columna 'metro'. Por ejemplo, si 'metro'
                                              # <- contiene nombres de ciudades como "Nueva York", "París", etc., estos pasarán a ser
                                              # <- las etiquetas de las filas.

#percapitaGDP.reset_index(inplace=True)       # <- Resetea
percapitaGDP.head()
# Out:
#                           año-2000  año-2001  año-2002  año-2003  año-2004  \
# metro
# AUS01: Greater Sydney          NaN   41091.0   41781.0   42988.0   43232.0
# AUS02: Greater Melbourne       NaN   40488.0   41136.0   42164.0   42810.0
# AUS03: Greater Brisbane        NaN   35276.0   35676.0   37092.0   38655.0
# AUS04: Greater Perth           NaN   43355.0   44849.0   46475.0   48692.0
# AUS05: Greater Adelaide        NaN   36081.0   36928.0   37491.0   37422.0
#
#                           año-2005  año-2006  año-2007  año-2008  año-2009  \
# metro
# AUS01: Greater Sydney      42807.0   42953.0   43162.0   42641.0   43194.0
# AUS02: Greater Melbourne   42195.0   42298.0   43148.0   41720.0   42138.0
# AUS03: Greater Brisbane    40712.0   42088.0   42222.0   43703.0   41315.0
# AUS04: Greater Perth       52804.0   57511.0   59741.0   60342.0   60556.0
# AUS05: Greater Adelaide    37304.0   37548.0   38349.0   37866.0   38666.0
#
#                           ...  año-2011  año-2012  año-2013  año-2014  \
# metro                     ...
# AUS01: Greater Sydney     ...   43762.0   44668.0   44669.0   45934.0
# AUS02: Greater Melbourne  ...   42118.0   42153.0   41920.0   42865.0
# AUS03: Greater Brisbane   ...   42083.0   41763.0   41446.0   41733.0
# AUS04: Greater Perth      ...   69432.0   68537.0   71841.0   66268.0
# AUS05: Greater Adelaide   ...   38514.0   38922.0   38851.0   39392.0
#
#                           año-2015  año-2016  año-2017  año-2018  año-2019  \
# metro
# AUS01: Greater Sydney      47349.0   47582.0   47569.0   47171.0   45576.0
# AUS02: Greater Melbourne   43725.0   43394.0   43772.0   43237.0   42299.0
# AUS03: Greater Brisbane    42294.0   43547.0   44663.0   44328.0   42145.0
# AUS04: Greater Perth       62519.0   62433.0   62686.0   67313.0   70970.0
# AUS05: Greater Adelaide    39472.0   38984.0   39302.0   39055.0   38314.0
#
#                           año-2020
# metro
# AUS01: Greater Sydney      45152.0
# AUS02: Greater Melbourne   40848.0
# AUS03: Greater Brisbane    40741.0
# AUS04: Greater Perth       78489.0
# AUS05: Greater Adelaide    39181.0
#
# [5 rows x 21 columns]

# %%
percapitaGDP.loc['AUS01: Greater Sydney']  # Devuelve la fila de AUS01: Greater Sydney.
# Out:
# año-2000        NaN
# año-2001    41091.0
# año-2002    41781.0
# año-2003    42988.0
# año-2004    43232.0
# año-2005    42807.0
# año-2006    42953.0
# año-2007    43162.0
# año-2008    42641.0
# año-2009    43194.0
# año-2010    42881.0
# año-2011    43762.0
# año-2012    44668.0
# año-2013    44669.0
# año-2014    45934.0
# año-2015    47349.0
# año-2016    47582.0
# año-2017    47569.0
# año-2018    47171.0
# año-2019    45576.0
# año-2020    45152.0
# Name: AUS01: Greater Sydney, dtype: float64

# %%
percapitaGDP.loc['AUS01: Greater Sydney':'AUS05: Greater Adelaide', 'año-2010':'año-2012'] # <- Seleccionar filas y columnas en particular
# Out:
#                           año-2010  año-2011  año-2012
# metro
# AUS01: Greater Sydney      42881.0   43762.0   44668.0
# AUS02: Greater Melbourne   41728.0   42118.0   42153.0
# AUS03: Greater Brisbane    40653.0   42083.0   41763.0
# AUS04: Greater Perth       66816.0   69432.0   68537.0
# AUS05: Greater Adelaide    38668.0   38514.0   38922.0

# %%
mostrar=[percapitaGDP.loc['AUS01: Greater Sydney']>43300] # <- aquí se seleccionan los valores que cumplen la condición
percapitaGDP.loc['AUS01: Greater Sydney'][mostrar[0]]     # <- aquí se muestran esos valores
# Out:
# año-2011    43762.0
# año-2012    44668.0
# año-2013    44669.0
# año-2014    45934.0
# año-2015    47349.0
# año-2016    47582.0
# año-2017    47569.0
# año-2018    47171.0
# año-2019    45576.0
# año-2020    45152.0
# Name: AUS01: Greater Sydney, dtype: float64

# %%
percapitaGDP['año-2004'][percapitaGDP['año-2004'] >45000] # Realizamos un procedimiento similar pero por columnas
                                                          # Sin usar loc, es mas sencillo pero hay menos control de las filas
# Out:
# metro
# AUS04: Greater Perth    48692.0
# AUS07: Canberra         47825.0
# AT001: Vienna           53608.0
# AT002: Graz             48084.0
# AT003: Linz             48729.0
#                          ...
# USA151: Santa Cruz      45011.0
# USA153: Minnehaha       62032.0
# USA155: Benton (WA)     46985.0
# USA157: Kalamazoo       48210.0
# USA170: Benton (AR)     48139.0
# Name: año-2004, Length: 182, dtype: float64

# %%
# Mostrar 'avgtemp' para las filas con índices 'A' a 'D'
mostrar=[percapitaGDP.loc['AUS01: Greater Sydney':'AUS04: Greater Perth', 'año-2004']>45000]
percapitaGDP.loc['AUS01: Greater Sydney':'AUS04: Greater Perth', 'año-2004'][mostrar[0]]
# Out:
# metro
# AUS04: Greater Perth    48692.0
# Name: año-2004, dtype: float64

# %%
# Mostrar para los años 2004 a 2007, las temperaturas que estivieron entre 38000.0 y 44000.0

# %%
FIN DE LA ACTIVIDAD EN CLASE

# %%
########################################  Resúmenes estadísticos  ############################################

# %%
# Resumen estadístico de la temperatura promedio
percapitaGDP.describe()
#percapitaGDP.temperatura_promedio.describe()
# Out:
#        año-2000  año-2001  año-2002   año-2003   año-2004  ...   año-2016  \
# count    158.00    450.00    479.00     566.00     586.00  ...     691.00
# mean  33,960.63 38,873.63 39,620.57  37,288.67  37,401.96  ...  40,142.34
# std   15,154.98 13,194.49 13,060.87  14,677.41  15,453.11  ...  16,446.00
# min    2,686.00  7,805.00  7,065.00   7,499.00   5,438.00  ...   5,443.00
# 25%   21,523.25 30,789.75 31,064.00  27,961.00  27,819.00  ...  29,907.00
# 50%   35,835.50 38,077.50 39,246.00  37,508.00  37,434.50  ...  39,900.00
# 75%   42,804.00 46,576.50 47,873.50  46,686.50  47,378.50  ...  49,979.00
# max   95,221.00 96,941.00 98,929.00 100,965.00 124,971.00  ... 111,923.00
#
#         año-2017   año-2018   año-2019   año-2020
# count     691.00     692.00     596.00     425.00
# mean   40,890.96  41,666.85  42,709.20  39,791.74
# std    16,637.25  17,439.52  18,892.73  19,229.55
# min     5,513.00   5,530.00   5,698.00   5,508.00
# 25%    30,316.50  31,321.50  29,760.00  24,142.00
# 50%    40,641.00  41,428.00  43,505.00  41,047.00
# 75%    50,798.00  51,130.50  53,647.25  51,130.00
# max   117,666.00 147,760.00 146,094.00 131,082.00
#
# [8 rows x 21 columns]

# %%
# Vamos a encontrar el 5% de los promedios mas bajos del año 2002, para eso, usamos quantile(0.05)
percapitaGDP["año-2002"].quantile(0.05)
# Out:
# np.float64(16333.2)

# %%
# Ahora vamos a seleccionar por ese valor encontrado
percapitaGDP["año-2002"]<=16333.2
# Out:
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
#        ...
# 726    False
# 727    False
# 728    False
# 729    False
# 730    False
# Name: año-2002, Length: 692, dtype: bool

# %%
percapitaGDP.loc[percapitaGDP["año-2002"]<=16333.2].iloc[0:5,15:]
# Out:
#      año-2014  año-2015  año-2016  año-2017  año-2018  año-2019  año-2020
# 28  13,983.00 15,061.00 16,111.00 16,577.00 17,177.00 18,008.00 17,431.00
# 29  18,470.00 18,768.00 18,638.00 19,168.00 20,236.00 20,343.00 18,608.00
# 30  13,918.00 15,508.00 16,532.00 17,066.00 16,443.00 16,732.00 13,317.00
# 294 17,268.00 17,888.00 18,739.00 19,457.00 20,112.00 21,560.00 19,432.00
# 297 16,638.00 18,947.00 19,142.00 21,214.00 22,188.00 21,805.00 21,279.00

# %%
#TAREA
#Vamos a encontrar el 5% de los promedios mas bajos del año 2002 y el 5% de los más altos, para eso, usamos quantile(0.05) y quantile(0.95)

# %%
percapitaGDP["año-2002"].quantile(0.995)
# Out:
# np.float64(76296.64000000004)

# %%
percapitaGDP.loc[(percapitaGDP["año-2002"]<=16333.2) | (percapitaGDP["año-2002"]>=76296.64)]
# Out:
#                               metro  año-2000  año-2001  año-2002   año-2003  \
# 28                   BG002: Plovdiv  7,979.00  8,504.00  8,895.00   9,737.00
# 29                     BG003: Varna 11,207.00 11,785.00 11,651.00  12,291.00
# 30                    BG004: Burgas 12,108.00  9,620.00 10,013.00  11,121.00
# 294                    HR005: Split       NaN 14,961.00 15,479.00  16,391.00
# 297                  HU002: Miskolc 11,948.00 12,481.00 12,866.00  13,497.00
# 298                     HU004: Pecs 13,912.00 14,385.00 15,323.00  15,980.00
# 299                 HU005: Debrecen 14,508.00 15,803.00 16,155.00  17,331.00
# 404                   LT002: Kaunas 11,872.00 13,414.00 14,024.00  15,882.00
# 406               LU001: Luxembourg 95,221.00 96,941.00 98,929.00 100,558.00
# 510                   PL009: Lublin 13,946.00 14,394.00 14,708.00  15,056.00
# 512                PL011: Bialystok 13,688.00 14,417.00 14,512.00  14,991.00
# 513                   PL012: Kielce 13,045.00 13,156.00 13,669.00  14,328.00
# 515                  PL014: Olsztyn 13,849.00 13,548.00 13,873.00  14,742.00
# 516                  PL015: Rzeszow 12,285.00 12,924.00 13,232.00  13,500.00
# 517                    PL016: Opole 14,165.00 13,909.00 14,178.00  14,507.00
# 518                PL020: Nowy Sacz 10,541.00 10,613.00 10,757.00  10,973.00
# 519              PL024: Czestochowa 13,933.00 15,051.00 14,662.00  15,144.00
# 520                    PL025: Radom 11,146.00 11,700.00 11,868.00  12,236.00
# 522                PL511: Walbrzych 12,079.00 12,645.00 12,815.00  13,468.00
# 523                   PL514: Tarnow 10,810.00 10,736.00 11,160.00  11,398.00
# 531                 RO002: Floresti 12,724.00 13,695.00 15,578.00  16,079.00
# 532                    RO003: Giroc 13,040.00 14,192.00 15,833.00  17,170.00
# 533           RO004: Simnicu De Sus  8,300.00  8,989.00  8,825.00   9,865.00
# 534                   RO012: Modelu  6,419.00  7,805.00  7,065.00   7,499.00
# 536              RO502: Schitu Duca  8,849.00  9,619.00 10,533.00  10,311.00
# 573  USA05: San Francisco (Greater)       NaN 80,157.00 77,554.00  79,050.00
# 716                  USA148: Durham       NaN 89,303.00 92,172.00  97,378.00
#
#      ...   año-2016   año-2017   año-2018   año-2019   año-2020
# 28   ...  16,111.00  16,577.00  17,177.00  18,008.00  17,431.00
# 29   ...  18,638.00  19,168.00  20,236.00  20,343.00  18,608.00
# 30   ...  16,532.00  17,066.00  16,443.00  16,732.00  13,317.00
# 294  ...  18,739.00  19,457.00  20,112.00  21,560.00  19,432.00
# 297  ...  19,142.00  21,214.00  22,188.00  21,805.00  21,279.00
# 298  ...  17,816.00  18,881.00  20,400.00  21,412.00  20,671.00
# 299  ...  18,933.00  20,554.00  21,835.00  22,648.00  21,747.00
# 404  ...  30,158.00  32,061.00  33,901.00  35,500.00        NaN
# 406  ... 111,923.00 110,630.00 110,722.00 112,143.00 108,002.00
# 510  ...  25,059.00  26,189.00  27,269.00  28,732.00        NaN
# 512  ...  22,900.00  23,893.00  25,212.00  26,638.00        NaN
# 513  ...  21,518.00  22,541.00  24,020.00  24,571.00        NaN
# 515  ...  22,348.00  22,754.00  23,524.00  24,718.00        NaN
# 516  ...  23,801.00  24,655.00  26,399.00  27,837.00        NaN
# 517  ...  25,586.00  26,717.00  28,252.00  29,431.00        NaN
# 518  ...  17,022.00  17,955.00  19,580.00  20,462.00        NaN
# 519  ...  23,747.00  25,048.00  26,096.00  27,747.00        NaN
# 520  ...  18,768.00  19,973.00  20,673.00  22,066.00        NaN
# 522  ...  20,583.00  21,175.00  22,236.00  22,913.00        NaN
# 523  ...  17,930.00  18,867.00  19,691.00  20,394.00        NaN
# 531  ...  30,002.00  34,343.00  35,276.00  37,188.00        NaN
# 532  ...  30,809.00  31,317.00  33,091.00  34,708.00        NaN
# 533  ...  16,584.00  18,369.00  19,914.00  20,939.00        NaN
# 534  ...  11,993.00  12,825.00  13,786.00  16,152.00        NaN
# 536  ...  17,510.00  20,234.00  20,851.00  21,322.00        NaN
# 573  ... 110,113.00 117,666.00 124,261.00 130,178.00 131,082.00
# 716  ... 104,230.00  99,418.00 102,980.00 107,335.00 109,031.00
#
# [27 rows x 22 columns]

# %%
# Vamos a importar otra base de datos más flexible para hacer estadísticas
nls97 = pd.read_csv("data/nls97.csv")
nls97
# Out:
#       personid  gender  birthmonth  birthyear  highestgradecompleted  ...  \
# 0       100061  Female           5       1980                  13.00  ...
# 1       100139    Male           9       1983                  12.00  ...
# 2       100284    Male          11       1984                   7.00  ...
# 3       100292    Male           4       1982                    NaN  ...
# 4       100583    Male           1       1980                  13.00  ...
# ...        ...     ...         ...        ...                    ...  ...
# 8979    999291  Female           4       1981                  16.00  ...
# 8980    999406    Male           7       1982                  14.00  ...
# 8981    999543  Female           8       1984                  12.00  ...
# 8982    999698  Female           5       1983                  12.00  ...
# 8983    999963  Female           9       1982                  17.00  ...
#
#           colenroct15      colenrfeb16      colenroct16      colenrfeb17  \
# 0     1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 1     1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 2     1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 3     1. Not enrolled              NaN              NaN              NaN
# 4     1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# ...               ...              ...              ...              ...
# 8979  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 8980  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 8981  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 8982  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 8983  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
#           colenroct17
# 0     1. Not enrolled
# 1     1. Not enrolled
# 2     1. Not enrolled
# 3                 NaN
# 4     1. Not enrolled
# ...               ...
# 8979  1. Not enrolled
# 8980  1. Not enrolled
# 8981  1. Not enrolled
# 8982  1. Not enrolled
# 8983  1. Not enrolled
#
# [8984 rows x 89 columns]

# %%
# Se define como indice la primera columna
nls97.set_index("personid",inplace=True)

# %%
nls97.index
# Out:
# Index([100061, 100139, 100284, 100292, 100583, 100833, 100931, 101089, 101122,
#        101132,
#        ...
#        998997, 999031, 999053, 999087, 999103, 999291, 999406, 999543, 999698,
#        999963],
#       dtype='int64', name='personid', length=8984)

# %%
nls97.shape
# Out:
# (8984, 88)

# %%
nls97.index.nunique()
# Out:
# 8984

# %%
nls97.head(3).T
# Out:
# personid                        100061           100139           100284
# gender                          Female             Male             Male
# birthmonth                           5                9               11
# birthyear                         1980             1983             1984
# highestgradecompleted            13.00            12.00             7.00
# maritalstatus                  Married          Married    Never-married
# ...                                ...              ...              ...
# colenroct15            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenrfeb16            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenroct16            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenrfeb17            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenroct17            1. Not enrolled  1. Not enrolled  1. Not enrolled
#
# [88 rows x 3 columns]

# %%
# Tips: si se quiere escoger columnas que empiecen con las mismas letras
nls97.filter(like="weeksworked")
# Out:
#           weeksworked00  weeksworked01  weeksworked02  weeksworked03  \
# personid
# 100061            46.00          52.00          52.00          48.00
# 100139             5.00          49.00          52.00          52.00
# 100284             5.00           8.00          52.00          35.00
# 100292            29.00          34.00          52.00          31.00
# 100583            53.00          52.00          52.00          52.00
# ...                 ...            ...            ...            ...
# 999291            27.00          52.00          52.00          33.00
# 999406            51.00          52.00          44.00          45.00
# 999543             0.00           0.00          20.00          23.00
# 999698             0.00          18.00          52.00           0.00
# 999963            45.00          50.00          52.00          52.00
#
#           weeksworked04  ...  weeksworked13  weeksworked14  weeksworked15  \
# personid                 ...
# 100061            52.00  ...          52.00          52.00          52.00
# 100139            52.00  ...          52.00          52.00          52.00
# 100284            40.00  ...            NaN          11.00          52.00
# 100292            52.00  ...          52.00          52.00          52.00
# 100583            48.00  ...          27.00           3.00          52.00
# ...                 ...  ...            ...            ...            ...
# 999291            15.00  ...          52.00          52.00          52.00
# 999406            52.00  ...          52.00          52.00          52.00
# 999543             8.00  ...          32.00          47.00          48.00
# 999698             0.00  ...           0.00           0.00           0.00
# 999963            38.00  ...          52.00          52.00          52.00
#
#           weeksworked16  weeksworked17
# personid
# 100061            48.00          48.00
# 100139            53.00          52.00
# 100284            47.00           0.00
# 100292             4.00            NaN
# 100583            53.00          52.00
# ...                 ...            ...
# 999291            53.00          52.00
# 999406            53.00          52.00
# 999543             0.00          30.00
# 999698             0.00           0.00
# 999963            53.00          52.00
#
# [8984 rows x 18 columns]

# %%
nls97.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8984 entries, 100061 to 999963
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8984 non-null   object
#  1   birthmonth             8984 non-null   int64
#  2   birthyear              8984 non-null   int64
#  3   highestgradecompleted  6663 non-null   float64
#  4   maritalstatus          6672 non-null   object
#  5   childathome            4791 non-null   float64
#  6   childnotathome         4791 non-null   float64
#  7   wageincome             5091 non-null   float64
#  8   weeklyhrscomputer      5792 non-null   object
#  9   weeklyhrstv            6711 non-null   object
#  10  nightlyhrssleep        6706 non-null   float64
#  11  satverbal              1406 non-null   float64
#  12  satmath                1407 non-null   float64
#  13  gpaoverall             6004 non-null   float64
#  14  gpaenglish             5798 non-null   float64
#  15  gpamath                5766 non-null   float64
#  16  gpascience             5684 non-null   float64
#  17  highestdegree          8953 non-null   object
#  18  govprovidejobs         1833 non-null   object
#  19  govpricecontrols       1859 non-null   object
#  20  govhealthcare          1874 non-null   object
#  21  govelderliving         1872 non-null   object
#  22  govindhelp             1815 non-null   object
#  23  govunemp               1811 non-null   object
#  24  govincomediff          1775 non-null   object
#  25  govcollegefinance      1875 non-null   object
#  26  govdecenthousing       1847 non-null   object
#  27  govprotectenvironment  1860 non-null   object
#  28  weeksworked00          8603 non-null   float64
#  29  weeksworked01          8564 non-null   float64
#  30  weeksworked02          8556 non-null   float64
#  31  weeksworked03          8490 non-null   float64
#  32  weeksworked04          8458 non-null   float64
#  33  weeksworked05          8403 non-null   float64
#  34  weeksworked06          8340 non-null   float64
#  35  weeksworked07          8272 non-null   float64
#  36  weeksworked08          8186 non-null   float64
#  37  weeksworked09          8146 non-null   float64
#  38  weeksworked10          8054 non-null   float64
#  39  weeksworked11          7968 non-null   float64
#  40  weeksworked12          7747 non-null   float64
#  41  weeksworked13          7680 non-null   float64
#  42  weeksworked14          7612 non-null   float64
#  43  weeksworked15          7389 non-null   float64
#  44  weeksworked16          7068 non-null   float64
#  45  weeksworked17          6670 non-null   float64
#  46  colenrfeb97            1250 non-null   object
#  47  colenroct97            8501 non-null   object
#  48  colenrfeb98            8501 non-null   object
#  49  colenroct98            8888 non-null   object
#  50  colenrfeb99            8865 non-null   object
#  51  colenroct99            8851 non-null   object
#  52  colenrfeb00            8820 non-null   object
#  53  colenroct00            8805 non-null   object
#  54  colenrfeb01            8786 non-null   object
#  55  colenroct01            8758 non-null   object
#  56  colenrfeb02            8732 non-null   object
#  57  colenroct02            8698 non-null   object
#  58  colenrfeb03            8658 non-null   object
#  59  colenroct03            8622 non-null   object
#  60  colenrfeb04            8578 non-null   object
#  61  colenroct04            8546 non-null   object
#  62  colenrfeb05            8508 non-null   object
#  63  colenroct05            8471 non-null   object
#  64  colenrfeb06            8426 non-null   object
#  65  colenroct06            8407 non-null   object
#  66  colenrfeb07            8352 non-null   object
#  67  colenroct07            8331 non-null   object
#  68  colenrfeb08            8289 non-null   object
#  69  colenroct08            8280 non-null   object
#  70  colenrfeb09            8236 non-null   object
#  71  colenroct09            8193 non-null   object
#  72  colenrfeb10            8116 non-null   object
#  73  colenroct10            8091 non-null   object
#  74  colenrfeb11            8037 non-null   object
#  75  colenroct11            7972 non-null   object
#  76  colenrfeb12            7794 non-null   object
#  77  colenroct12            7754 non-null   object
#  78  colenrfeb13            7754 non-null   object
#  79  colenroct13            7754 non-null   object
#  80  colenrfeb14            7624 non-null   object
#  81  colenroct14            7469 non-null   object
#  82  colenrfeb15            7469 non-null   object
#  83  colenroct15            7469 non-null   object
#  84  colenrfeb16            7036 non-null   object
#  85  colenroct16            6733 non-null   object
#  86  colenrfeb17            6733 non-null   object
#  87  colenroct17            6734 non-null   object
# dtypes: float64(29), int64(2), object(57)
# memory usage: 6.4+ MB

# %% [raw]
# ######################## Seleccionar multiples filas condicionalmente usando índices lógicos. ########################

# %%
nls97["nightlyhrssleep"]
# Out:
# personid
# 100061   6.00
# 100139   8.00
# 100284   7.00
# 100292    NaN
# 100583   6.00
#          ...
# 999291   7.00
# 999406   6.00
# 999543   6.00
# 999698   6.00
# 999963   6.00
# Name: nightlyhrssleep, Length: 8984, dtype: float64

# %%
# Vamos a encontrar el 5% de las personas que duermen menos, para eso, usamos quantile(0.05)
nls97.nightlyhrssleep.quantile(0.05)
# Out:
# np.float64(4.0)

# %%
# Ahora vamos a seleccionar por ese valor encontrado
nls97.nightlyhrssleep<=4
# Out:
# personid
# 100061    False
# 100139    False
# 100284    False
# 100292    False
# 100583    False
#           ...
# 999291    False
# 999406    False
# 999543    False
# 999698    False
# 999963    False
# Name: nightlyhrssleep, Length: 8984, dtype: bool

# %%
nls97.loc[nls97.nightlyhrssleep<=4].iloc[0:5,0:4]
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted
# personid
# 101414      Male           6       1984                  12.00
# 102454      Male           4       1982                  16.00
# 107334      Male          11       1982                  11.00
# 109316    Female           9       1982                   8.00
# 111733    Female           2       1984                  11.00

# %%
nls97.nightlyhrssleep.count()
# Out:
# np.int64(6706)

# %%
nls97.loc[nls97.nightlyhrssleep<=4]["nightlyhrssleep"].describe()
# Out:
# count   364.00
# mean      3.61
# std       0.82
# min       0.00
# 25%       4.00
# 50%       4.00
# 75%       4.00
# max       4.00
# Name: nightlyhrssleep, dtype: float64

# %% [raw]
# Seleccionar filas basado en múltiples condiciones

# %%
#         The criteria for rows appear before the comma.         The columns to select appear after the comma
nls97.loc[(nls97.nightlyhrssleep<=4) & (nls97.childathome>=3), ['nightlyhrssleep','childathome']].iloc[50:55,0:2]
# Out:
#           nightlyhrssleep  childathome
# personid
# 597261               3.00         4.00
# 618981               3.00         3.00
# 621025               4.00         3.00
# 623691               4.00         4.00
# 624749               4.00         4.00

# %% [raw]
# Vamos a generar frecuencias con variables categóricas
# nls97[nls97.select_dtypes(['object']).columns] = -- .transform(lambda x: x.astype('category'))

# %%
# Recordemos que tipos de variables tiene el archivo de datos
nls97.dtypes
# Out:
# gender                    object
# birthmonth                 int64
# birthyear                  int64
# highestgradecompleted    float64
# maritalstatus             object
#                           ...
# colenroct15               object
# colenrfeb16               object
# colenroct16               object
# colenrfeb17               object
# colenroct17               object
# Length: 88, dtype: object

# %%
# la idea ahora es seleccionar todas las variables de tipo objeto para convertirlas a categóricas
nls97.select_dtypes(['object']).shape
# Out:
# (8984, 57)

# %%
nls97.select_dtypes(['object']).columns
# Out:
# Index(['gender', 'maritalstatus', 'weeklyhrscomputer', 'weeklyhrstv',
#        'highestdegree', 'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing', 'govprotectenvironment',
#        'colenrfeb97', 'colenroct97', 'colenrfeb98', 'colenroct98',
#        'colenrfeb99', 'colenroct99', 'colenrfeb00', 'colenroct00',
#        'colenrfeb01', 'colenroct01', 'colenrfeb02', 'colenroct02',
#        'colenrfeb03', 'colenroct03', 'colenrfeb04', 'colenroct04',
#        'colenrfeb05', 'colenroct05', 'colenrfeb06', 'colenroct06',
#        'colenrfeb07', 'colenroct07', 'colenrfeb08', 'colenroct08',
#        'colenrfeb09', 'colenroct09', 'colenrfeb10', 'colenroct10',
#        'colenrfeb11', 'colenroct11', 'colenrfeb12', 'colenroct12',
#        'colenrfeb13', 'colenroct13', 'colenrfeb14', 'colenroct14',
#        'colenrfeb15', 'colenroct15', 'colenrfeb16', 'colenroct16',
#        'colenrfeb17', 'colenroct17'],
#       dtype='object')

# %%
nls97[nls97.select_dtypes(['object']).columns]
# Out:
#           gender  maritalstatus        weeklyhrscomputer  \
# personid
# 100061    Female        Married  10 hours or more a week
# 100139      Male        Married      1 to 3 hours a week
# 100284      Male  Never-married                      NaN
# 100292      Male            NaN                      NaN
# 100583      Male        Married  Less than 1 hour a week
# ...          ...            ...                      ...
# 999291    Female        Married      7 to 9 hours a week
# 999406      Male  Never-married      4 to 6 hours a week
# 999543    Female       Divorced                      NaN
# 999698    Female  Never-married      4 to 6 hours a week
# 999963    Female        Married      4 to 6 hours a week
#
#                          weeklyhrstv   highestdegree  ...      colenroct15  \
# personid                                              ...
# 100061         11 to 20 hours a week  2. High School  ...  1. Not enrolled
# 100139          3 to 10 hours a week  2. High School  ...  1. Not enrolled
# 100284         11 to 20 hours a week         0. None  ...  1. Not enrolled
# 100292                           NaN    4. Bachelors  ...  1. Not enrolled
# 100583          3 to 10 hours a week  2. High School  ...  1. Not enrolled
# ...                              ...             ...  ...              ...
# 999291    Less than 2 hours per week    4. Bachelors  ...  1. Not enrolled
# 999406          3 to 10 hours a week  2. High School  ...  1. Not enrolled
# 999543          3 to 10 hours a week  2. High School  ...  1. Not enrolled
# 999698     More than 40 hours a week  2. High School  ...  1. Not enrolled
# 999963          3 to 10 hours a week    4. Bachelors  ...  1. Not enrolled
#
#               colenrfeb16      colenroct16      colenrfeb17      colenroct17
# personid
# 100061    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100139    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100284    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100292                NaN              NaN              NaN              NaN
# 100583    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# ...                   ...              ...              ...              ...
# 999291    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 999406    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 999543    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 999698    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 999963    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
# [8984 rows x 57 columns]

# %%
nls97[nls97.select_dtypes(['object']).columns] = nls97.select_dtypes(['object']).transform(lambda x: x.astype('category'))

# %% [raw]
# Mostrar los nombres de las columnas que contienen datos del tipo "categóricos"y comprobar el número de valores que faltan

# %%
nls97.select_dtypes(include=["category"]).columns
# Out:
# Index(['gender', 'maritalstatus', 'weeklyhrscomputer', 'weeklyhrstv',
#        'highestdegree', 'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing', 'govprotectenvironment',
#        'colenrfeb97', 'colenroct97', 'colenrfeb98', 'colenroct98',
#        'colenrfeb99', 'colenroct99', 'colenrfeb00', 'colenroct00',
#        'colenrfeb01', 'colenroct01', 'colenrfeb02', 'colenroct02',
#        'colenrfeb03', 'colenroct03', 'colenrfeb04', 'colenroct04',
#        'colenrfeb05', 'colenroct05', 'colenrfeb06', 'colenroct06',
#        'colenrfeb07', 'colenroct07', 'colenrfeb08', 'colenroct08',
#        'colenrfeb09', 'colenroct09', 'colenrfeb10', 'colenroct10',
#        'colenrfeb11', 'colenroct11', 'colenrfeb12', 'colenroct12',
#        'colenrfeb13', 'colenroct13', 'colenrfeb14', 'colenroct14',
#        'colenrfeb15', 'colenroct15', 'colenrfeb16', 'colenroct16',
#        'colenrfeb17', 'colenroct17'],
#       dtype='object')

# %%
nls97[nls97.select_dtypes(include=["category"]).columns].isnull().sum()#.iloc[1:10:2]
# Out:
# gender                      0
# maritalstatus            2312
# weeklyhrscomputer        3192
# weeklyhrstv              2273
# highestdegree              31
# govprovidejobs           7151
# govpricecontrols         7125
# govhealthcare            7110
# govelderliving           7112
# govindhelp               7169
# govunemp                 7173
# govincomediff            7209
# govcollegefinance        7109
# govdecenthousing         7137
# govprotectenvironment    7124
# colenrfeb97              7734
# colenroct97               483
# colenrfeb98               483
# colenroct98                96
# colenrfeb99               119
# colenroct99               133
# colenrfeb00               164
# colenroct00               179
# colenrfeb01               198
# colenroct01               226
# colenrfeb02               252
# colenroct02               286
# colenrfeb03               326
# colenroct03               362
# colenrfeb04               406
# colenroct04               438
# colenrfeb05               476
# colenroct05               513
# colenrfeb06               558
# colenroct06               577
# colenrfeb07               632
# colenroct07               653
# colenrfeb08               695
# colenroct08               704
# colenrfeb09               748
# colenroct09               791
# colenrfeb10               868
# colenroct10               893
# colenrfeb11               947
# colenroct11              1012
# colenrfeb12              1190
# colenroct12              1230
# colenrfeb13              1230
# colenroct13              1230
# colenrfeb14              1360
# colenroct14              1515
# colenrfeb15              1515
# colenroct15              1515
# colenrfeb16              1948
# colenroct16              2251
# colenrfeb17              2251
# colenroct17              2250
# dtype: int64

# %%
# Muestra las frecuencias para el estado civil:
nls97.maritalstatus.value_counts(sort=False)
# Out:
# maritalstatus
# Divorced          663
# Married          3066
# Never-married    2766
# Separated         154
# Widowed            23
# Name: count, dtype: int64

# %%
# Muestre porcentajes en lugar de contarlas:
# Esto tambien se puede hacer calculando el total: nls97.maritalstatus.value_counts(sort=False).sum() y luego dividiendo cada valor
# nls97.maritalstatus.value_counts(sort=False)/la_suma
nls97.maritalstatus.value_counts(sort=False, normalize=True)
# Out:
# maritalstatus
# Divorced        0.10
# Married         0.46
# Never-married   0.41
# Separated       0.02
# Widowed         0.00
# Name: proportion, dtype: float64

# %%
# Muestra los porcentajes de todas las columnas de responsabilidad gubernamental.
nls97.filter(like="gov").apply(pd.Series.value_counts, normalize=True)
# Out:
#                    govprovidejobs  govpricecontrols  govhealthcare  \
# 1. Definitely                0.25              0.54           0.67
# 2. Probably                  0.34              0.33           0.27
# 3. Probably not              0.25              0.09           0.05
# 4. Definitely not            0.16              0.04           0.02
#
#                    govelderliving  govindhelp  govunemp  govincomediff  \
# 1. Definitely                0.70        0.43      0.22           0.32
# 2. Probably                  0.25        0.41      0.40           0.28
# 3. Probably not              0.04        0.12      0.26           0.23
# 4. Definitely not            0.01        0.04      0.12           0.16
#
#                    govcollegefinance  govdecenthousing  govprotectenvironment
# 1. Definitely                   0.73              0.44                   0.67
# 2. Probably                     0.23              0.43                   0.29
# 3. Probably not                 0.03              0.10                   0.03
# 4. Definitely not               0.01              0.02                   0.02

# %%
# Halla los porcentajes, para todas las columnas de responsabilidad gubernamental, de personas que están casadas.

nls97[nls97.maritalstatus=="Married"].filter(like="gov").apply(pd.Series.value_counts, normalize=True)
# Out:
#                    govprovidejobs  govpricecontrols  govhealthcare  \
# 1. Definitely                0.17              0.46           0.56
# 2. Probably                  0.33              0.38           0.36
# 3. Probably not              0.31              0.11           0.05
# 4. Definitely not            0.18              0.05           0.02
#
#                    govelderliving  govindhelp  govunemp  govincomediff  \
# 1. Definitely                0.63        0.37      0.15           0.26
# 2. Probably                  0.31        0.45      0.40           0.27
# 3. Probably not              0.04        0.14      0.33           0.28
# 4. Definitely not            0.02        0.04      0.13           0.18
#
#                    govcollegefinance  govdecenthousing  govprotectenvironment
# 1. Definitely                   0.70              0.36                   0.64
# 2. Probably                     0.26              0.49                   0.31
# 3. Probably not                 0.03              0.12                   0.03
# 4. Definitely not               0.01              0.03                   0.01

# %% [raw]
# # Encuentre las frecuencias y porcentajes para todas las columnas de tipo categóricas en el DataFrame.
#
# with open("frecuencias.txt", "w") as freqout:
#     for col in nls97.select_dtypes(include=["category"]):
#         print(
#             col,
#             "----------------------",
#             "frequencies",
#             nls97[col].value_counts(sort=False),
#             "percentages",
#             nls97[col].value_counts(normalize=True, sort=False),
#             sep="\n\n",
#             end="\n\n\n",
#             file=freqout
#         )

# %%
for col in nls97.select_dtypes(include=["category"]):
    print(
        col,
        "----------------------",
        "frequencies",
        nls97[col].value_counts(sort=False),
        "percentages",
        nls97[col].value_counts(normalize=True, sort=False),
        sep="\n\n",
        end="\n\n\n"
    )
# Out:
# gender
#
# ----------------------
#
# frequencies
#
# gender
# Female    4385
# Male      4599
# Name: count, dtype: int64
#
# percentages
#
# gender
# Female   0.49
# Male     0.51
# Name: proportion, dtype: float64
#
#
# maritalstatus
#
# ----------------------
#
# frequencies
#
# maritalstatus
# Divorced          663
# Married          3066
# Never-married    2766
# Separated         154
# Widowed            23
# Name: count, dtype: int64
#
# percentages
#
# maritalstatus
# Divorced        0.10
# Married         0.46
# Never-married   0.41
# Separated       0.02
# Widowed         0.00
# Name: proportion, dtype: float64
#
#
# weeklyhrscomputer
#
# ----------------------
#
# frequencies
#
# weeklyhrscomputer
# 1 to 3 hours a week         733
# 10 hours or more a week    3669
# 4 to 6 hours a week         726
# 7 to 9 hours a week         368
# Less than 1 hour a week     296
# Name: count, dtype: int64
#
# percentages
#
# weeklyhrscomputer
# 1 to 3 hours a week       0.13
# 10 hours or more a week   0.63
# 4 to 6 hours a week       0.13
# 7 to 9 hours a week       0.06
# Less than 1 hour a week   0.05
# Name: proportion, dtype: float64
#
#
# weeklyhrstv
#
# ----------------------
#
# frequencies
#
# weeklyhrstv
# 11 to 20 hours a week         1145
# 21 to 30 hours a week          299
# 3 to 10 hours a week          3625
# 31 to 40 hours a week          116
# Less than 2 hours per week    1350
# More than 40 hours a week      176
# Name: count, dtype: int64
#
# percentages
#
# weeklyhrstv
# 11 to 20 hours a week        0.17
# 21 to 30 hours a week        0.04
# 3 to 10 hours a week         0.54
# 31 to 40 hours a week        0.02
# Less than 2 hours per week   0.20
# More than 40 hours a week    0.03
# Name: proportion, dtype: float64
#
#
# highestdegree
#
# ----------------------
#
# frequencies
#
# highestdegree
# 0. None             953
# 1. GED             1146
# 2. High School     3667
# 3. Associates       737
# 4. Bachelors       1673
# 5. Masters          603
# 6. PhD               54
# 7. Professional     120
# Name: count, dtype: int64
#
# percentages
#
# highestdegree
# 0. None           0.11
# 1. GED            0.13
# 2. High School    0.41
# 3. Associates     0.08
# 4. Bachelors      0.19
# 5. Masters        0.07
# 6. PhD            0.01
# 7. Professional   0.01
# Name: proportion, dtype: float64
#
#
# govprovidejobs
#
# ----------------------
#
# frequencies
#
# govprovidejobs
# 1. Definitely        454
# 2. Probably          617
# 3. Probably not      462
# 4. Definitely not    300
# Name: count, dtype: int64
#
# percentages
#
# govprovidejobs
# 1. Definitely       0.25
# 2. Probably         0.34
# 3. Probably not     0.25
# 4. Definitely not   0.16
# Name: proportion, dtype: float64
#
#
# govpricecontrols
#
# ----------------------
#
# frequencies
#
# govpricecontrols
# 1. Definitely        1007
# 2. Probably           621
# 3. Probably not       161
# 4. Definitely not      70
# Name: count, dtype: int64
#
# percentages
#
# govpricecontrols
# 1. Definitely       0.54
# 2. Probably         0.33
# 3. Probably not     0.09
# 4. Definitely not   0.04
# Name: proportion, dtype: float64
#
#
# govhealthcare
#
# ----------------------
#
# frequencies
#
# govhealthcare
# 1. Definitely        1247
# 2. Probably           508
# 3. Probably not        85
# 4. Definitely not      34
# Name: count, dtype: int64
#
# percentages
#
# govhealthcare
# 1. Definitely       0.67
# 2. Probably         0.27
# 3. Probably not     0.05
# 4. Definitely not   0.02
# Name: proportion, dtype: float64
#
#
# govelderliving
#
# ----------------------
#
# frequencies
#
# govelderliving
# 1. Definitely        1311
# 2. Probably           464
# 3. Probably not        71
# 4. Definitely not      26
# Name: count, dtype: int64
#
# percentages
#
# govelderliving
# 1. Definitely       0.70
# 2. Probably         0.25
# 3. Probably not     0.04
# 4. Definitely not   0.01
# Name: proportion, dtype: float64
#
#
# govindhelp
#
# ----------------------
#
# frequencies
#
# govindhelp
# 1. Definitely        778
# 2. Probably          746
# 3. Probably not      216
# 4. Definitely not     75
# Name: count, dtype: int64
#
# percentages
#
# govindhelp
# 1. Definitely       0.43
# 2. Probably         0.41
# 3. Probably not     0.12
# 4. Definitely not   0.04
# Name: proportion, dtype: float64
#
#
# govunemp
#
# ----------------------
#
# frequencies
#
# govunemp
# 1. Definitely        395
# 2. Probably          730
# 3. Probably not      476
# 4. Definitely not    210
# Name: count, dtype: int64
#
# percentages
#
# govunemp
# 1. Definitely       0.22
# 2. Probably         0.40
# 3. Probably not     0.26
# 4. Definitely not   0.12
# Name: proportion, dtype: float64
#
#
# govincomediff
#
# ----------------------
#
# frequencies
#
# govincomediff
# 1. Definitely        576
# 2. Probably          505
# 3. Probably not      406
# 4. Definitely not    288
# Name: count, dtype: int64
#
# percentages
#
# govincomediff
# 1. Definitely       0.32
# 2. Probably         0.28
# 3. Probably not     0.23
# 4. Definitely not   0.16
# Name: proportion, dtype: float64
#
#
# govcollegefinance
#
# ----------------------
#
# frequencies
#
# govcollegefinance
# 1. Definitely        1377
# 2. Probably           432
# 3. Probably not        50
# 4. Definitely not      16
# Name: count, dtype: int64
#
# percentages
#
# govcollegefinance
# 1. Definitely       0.73
# 2. Probably         0.23
# 3. Probably not     0.03
# 4. Definitely not   0.01
# Name: proportion, dtype: float64
#
#
# govdecenthousing
#
# ----------------------
#
# frequencies
#
# govdecenthousing
# 1. Definitely        817
# 2. Probably          801
# 3. Probably not      185
# 4. Definitely not     44
# Name: count, dtype: int64
#
# percentages
#
# govdecenthousing
# 1. Definitely       0.44
# 2. Probably         0.43
# 3. Probably not     0.10
# 4. Definitely not   0.02
# Name: proportion, dtype: float64
#
#
# govprotectenvironment
#
# ----------------------
#
# frequencies
#
# govprotectenvironment
# 1. Definitely        1244
# 2. Probably           533
# 3. Probably not        55
# 4. Definitely not      28
# Name: count, dtype: int64
#
# percentages
#
# govprotectenvironment
# 1. Definitely       0.67
# 2. Probably         0.29
# 3. Probably not     0.03
# 4. Definitely not   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb97
#
# ----------------------
#
# frequencies
#
# colenrfeb97
# 1. Not enrolled      1248
# 3. 4-year college       2
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb97
# 1. Not enrolled     1.00
# 3. 4-year college   0.00
# Name: proportion, dtype: float64
#
#
# colenroct97
#
# ----------------------
#
# frequencies
#
# colenroct97
# 1. Not enrolled       8475
# 2. 2-year college       14
# 3. 4-year college       12
# Name: count, dtype: int64
#
# percentages
#
# colenroct97
# 1. Not enrolled      1.00
# 2. 2-year college    0.00
# 3. 4-year college    0.00
# Name: proportion, dtype: float64
#
#
# colenrfeb98
#
# ----------------------
#
# frequencies
#
# colenrfeb98
# 1. Not enrolled       8473
# 2. 2-year college       15
# 3. 4-year college       13
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb98
# 1. Not enrolled      1.00
# 2. 2-year college    0.00
# 3. 4-year college    0.00
# Name: proportion, dtype: float64
#
#
# colenroct98
#
# ----------------------
#
# frequencies
#
# colenroct98
# 1. Not enrolled       8482
# 2. 2-year college      148
# 3. 4-year college      258
# Name: count, dtype: int64
#
# percentages
#
# colenroct98
# 1. Not enrolled      0.95
# 2. 2-year college    0.02
# 3. 4-year college    0.03
# Name: proportion, dtype: float64
#
#
# colenrfeb99
#
# ----------------------
#
# frequencies
#
# colenrfeb99
# 1. Not enrolled       8434
# 2. 2-year college      166
# 3. 4-year college      265
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb99
# 1. Not enrolled      0.95
# 2. 2-year college    0.02
# 3. 4-year college    0.03
# Name: proportion, dtype: float64
#
#
# colenroct99
#
# ----------------------
#
# frequencies
#
# colenroct99
# 1. Not enrolled       7729
# 2. 2-year college      371
# 3. 4-year college      751
# Name: count, dtype: int64
#
# percentages
#
# colenroct99
# 1. Not enrolled      0.87
# 2. 2-year college    0.04
# 3. 4-year college    0.08
# Name: proportion, dtype: float64
#
#
# colenrfeb00
#
# ----------------------
#
# frequencies
#
# colenrfeb00
# 1. Not enrolled       7680
# 2. 2-year college      395
# 3. 4-year college      745
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb00
# 1. Not enrolled      0.87
# 2. 2-year college    0.04
# 3. 4-year college    0.08
# Name: proportion, dtype: float64
#
#
# colenroct00
#
# ----------------------
#
# frequencies
#
# colenroct00
# 1. Not enrolled       7055
# 2. 2-year college      582
# 3. 4-year college     1168
# Name: count, dtype: int64
#
# percentages
#
# colenroct00
# 1. Not enrolled      0.80
# 2. 2-year college    0.07
# 3. 4-year college    0.13
# Name: proportion, dtype: float64
#
#
# colenrfeb01
#
# ----------------------
#
# frequencies
#
# colenrfeb01
# 1. Not enrolled       7035
# 2. 2-year college      598
# 3. 4-year college     1153
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb01
# 1. Not enrolled      0.80
# 2. 2-year college    0.07
# 3. 4-year college    0.13
# Name: proportion, dtype: float64
#
#
# colenroct01
#
# ----------------------
#
# frequencies
#
# colenroct01
# 1. Not enrolled       6387
# 2. 2-year college      751
# 3. 4-year college     1620
# Name: count, dtype: int64
#
# percentages
#
# colenroct01
# 1. Not enrolled      0.73
# 2. 2-year college    0.09
# 3. 4-year college    0.18
# Name: proportion, dtype: float64
#
#
# colenrfeb02
#
# ----------------------
#
# frequencies
#
# colenrfeb02
# 1. Not enrolled       6367
# 2. 2-year college      768
# 3. 4-year college     1597
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb02
# 1. Not enrolled      0.73
# 2. 2-year college    0.09
# 3. 4-year college    0.18
# Name: proportion, dtype: float64
#
#
# colenroct02
#
# ----------------------
#
# frequencies
#
# colenroct02
# 1. Not enrolled       5777
# 2. 2-year college      906
# 3. 4-year college     2015
# Name: count, dtype: int64
#
# percentages
#
# colenroct02
# 1. Not enrolled      0.66
# 2. 2-year college    0.10
# 3. 4-year college    0.23
# Name: proportion, dtype: float64
#
#
# colenrfeb03
#
# ----------------------
#
# frequencies
#
# colenrfeb03
# 1. Not enrolled       5768
# 2. 2-year college      894
# 3. 4-year college     1996
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb03
# 1. Not enrolled      0.67
# 2. 2-year college    0.10
# 3. 4-year college    0.23
# Name: proportion, dtype: float64
#
#
# colenroct03
#
# ----------------------
#
# frequencies
#
# colenroct03
# 1. Not enrolled        5778
# 2. 2-year college       869
# 3. 4-year college      1974
# 4. Graduate program       1
# Name: count, dtype: int64
#
# percentages
#
# colenroct03
# 1. Not enrolled       0.67
# 2. 2-year college     0.10
# 3. 4-year college     0.23
# 4. Graduate program   0.00
# Name: proportion, dtype: float64
#
#
# colenrfeb04
#
# ----------------------
#
# frequencies
#
# colenrfeb04
# 1. Not enrolled        5881
# 2. 2-year college       803
# 3. 4-year college      1885
# 4. Graduate program       9
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb04
# 1. Not enrolled       0.69
# 2. 2-year college     0.09
# 3. 4-year college     0.22
# 4. Graduate program   0.00
# Name: proportion, dtype: float64
#
#
# colenroct04
#
# ----------------------
#
# frequencies
#
# colenroct04
# 1. Not enrolled        6142
# 2. 2-year college       687
# 3. 4-year college      1664
# 4. Graduate program      53
# Name: count, dtype: int64
#
# percentages
#
# colenroct04
# 1. Not enrolled       0.72
# 2. 2-year college     0.08
# 3. 4-year college     0.19
# 4. Graduate program   0.01
# Name: proportion, dtype: float64
#
#
# colenrfeb05
#
# ----------------------
#
# frequencies
#
# colenrfeb05
# 1. Not enrolled        6216
# 2. 2-year college       629
# 3. 4-year college      1599
# 4. Graduate program      64
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb05
# 1. Not enrolled       0.73
# 2. 2-year college     0.07
# 3. 4-year college     0.19
# 4. Graduate program   0.01
# Name: proportion, dtype: float64
#
#
# colenroct05
#
# ----------------------
#
# frequencies
#
# colenroct05
# 1. Not enrolled        6500
# 2. 2-year college       514
# 3. 4-year college      1342
# 4. Graduate program     115
# Name: count, dtype: int64
#
# percentages
#
# colenroct05
# 1. Not enrolled       0.77
# 2. 2-year college     0.06
# 3. 4-year college     0.16
# 4. Graduate program   0.01
# Name: proportion, dtype: float64
#
#
# colenrfeb06
#
# ----------------------
#
# frequencies
#
# colenrfeb06
# 1. Not enrolled        6596
# 2. 2-year college       485
# 3. 4-year college      1222
# 4. Graduate program     123
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb06
# 1. Not enrolled       0.78
# 2. 2-year college     0.06
# 3. 4-year college     0.15
# 4. Graduate program   0.01
# Name: proportion, dtype: float64
#
#
# colenroct06
#
# ----------------------
#
# frequencies
#
# colenroct06
# 1. Not enrolled        6856
# 2. 2-year college       422
# 3. 4-year college       947
# 4. Graduate program     182
# Name: count, dtype: int64
#
# percentages
#
# colenroct06
# 1. Not enrolled       0.82
# 2. 2-year college     0.05
# 3. 4-year college     0.11
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb07
#
# ----------------------
#
# frequencies
#
# colenrfeb07
# 1. Not enrolled        6955
# 2. 2-year college       396
# 3. 4-year college       819
# 4. Graduate program     182
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb07
# 1. Not enrolled       0.83
# 2. 2-year college     0.05
# 3. 4-year college     0.10
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct07
#
# ----------------------
#
# frequencies
#
# colenroct07
# 1. Not enrolled        7056
# 2. 2-year college       402
# 3. 4-year college       653
# 4. Graduate program     220
# Name: count, dtype: int64
#
# percentages
#
# colenroct07
# 1. Not enrolled       0.85
# 2. 2-year college     0.05
# 3. 4-year college     0.08
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenrfeb08
#
# ----------------------
#
# frequencies
#
# colenrfeb08
# 1. Not enrolled        7145
# 2. 2-year college       348
# 3. 4-year college       583
# 4. Graduate program     213
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb08
# 1. Not enrolled       0.86
# 2. 2-year college     0.04
# 3. 4-year college     0.07
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenroct08
#
# ----------------------
#
# frequencies
#
# colenroct08
# 1. Not enrolled        7141
# 2. 2-year college       364
# 3. 4-year college       526
# 4. Graduate program     249
# Name: count, dtype: int64
#
# percentages
#
# colenroct08
# 1. Not enrolled       0.86
# 2. 2-year college     0.04
# 3. 4-year college     0.06
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenrfeb09
#
# ----------------------
#
# frequencies
#
# colenrfeb09
# 1. Not enrolled        7208
# 2. 2-year college       342
# 3. 4-year college       445
# 4. Graduate program     241
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb09
# 1. Not enrolled       0.88
# 2. 2-year college     0.04
# 3. 4-year college     0.05
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenroct09
#
# ----------------------
#
# frequencies
#
# colenroct09
# 1. Not enrolled        7081
# 2. 2-year college       409
# 3. 4-year college       448
# 4. Graduate program     255
# Name: count, dtype: int64
#
# percentages
#
# colenroct09
# 1. Not enrolled       0.86
# 2. 2-year college     0.05
# 3. 4-year college     0.05
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenrfeb10
#
# ----------------------
#
# frequencies
#
# colenrfeb10
# 1. Not enrolled        7091
# 2. 2-year college       369
# 3. 4-year college       409
# 4. Graduate program     247
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb10
# 1. Not enrolled       0.87
# 2. 2-year college     0.05
# 3. 4-year college     0.05
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenroct10
#
# ----------------------
#
# frequencies
#
# colenroct10
# 1. Not enrolled        7073
# 2. 2-year college       363
# 3. 4-year college       413
# 4. Graduate program     242
# Name: count, dtype: int64
#
# percentages
#
# colenroct10
# 1. Not enrolled       0.87
# 2. 2-year college     0.04
# 3. 4-year college     0.05
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenrfeb11
#
# ----------------------
#
# frequencies
#
# colenrfeb11
# 1. Not enrolled        7086
# 2. 2-year college       366
# 3. 4-year college       358
# 4. Graduate program     227
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb11
# 1. Not enrolled       0.88
# 2. 2-year college     0.05
# 3. 4-year college     0.04
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenroct11
#
# ----------------------
#
# frequencies
#
# colenroct11
# 1. Not enrolled        7043
# 2. 2-year college       348
# 3. 4-year college       363
# 4. Graduate program     218
# Name: count, dtype: int64
#
# percentages
#
# colenroct11
# 1. Not enrolled       0.88
# 2. 2-year college     0.04
# 3. 4-year college     0.05
# 4. Graduate program   0.03
# Name: proportion, dtype: float64
#
#
# colenrfeb12
#
# ----------------------
#
# frequencies
#
# colenrfeb12
# 1. Not enrolled        6951
# 2. 2-year college       314
# 3. 4-year college       340
# 4. Graduate program     189
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb12
# 1. Not enrolled       0.89
# 2. 2-year college     0.04
# 3. 4-year college     0.04
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct12
#
# ----------------------
#
# frequencies
#
# colenroct12
# 1. Not enrolled        7023
# 2. 2-year college       270
# 3. 4-year college       309
# 4. Graduate program     152
# Name: count, dtype: int64
#
# percentages
#
# colenroct12
# 1. Not enrolled       0.91
# 2. 2-year college     0.03
# 3. 4-year college     0.04
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb13
#
# ----------------------
#
# frequencies
#
# colenrfeb13
# 1. Not enrolled        7051
# 2. 2-year college       262
# 3. 4-year college       288
# 4. Graduate program     153
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb13
# 1. Not enrolled       0.91
# 2. 2-year college     0.03
# 3. 4-year college     0.04
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct13
#
# ----------------------
#
# frequencies
#
# colenroct13
# 1. Not enrolled        7044
# 2. 2-year college       250
# 3. 4-year college       302
# 4. Graduate program     158
# Name: count, dtype: int64
#
# percentages
#
# colenroct13
# 1. Not enrolled       0.91
# 2. 2-year college     0.03
# 3. 4-year college     0.04
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb14
#
# ----------------------
#
# frequencies
#
# colenrfeb14
# 1. Not enrolled        6974
# 2. 2-year college       229
# 3. 4-year college       273
# 4. Graduate program     148
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb14
# 1. Not enrolled       0.91
# 2. 2-year college     0.03
# 3. 4-year college     0.04
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct14
#
# ----------------------
#
# frequencies
#
# colenroct14
# 1. Not enrolled        6883
# 2. 2-year college       197
# 3. 4-year college       253
# 4. Graduate program     136
# Name: count, dtype: int64
#
# percentages
#
# colenroct14
# 1. Not enrolled       0.92
# 2. 2-year college     0.03
# 3. 4-year college     0.03
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb15
#
# ----------------------
#
# frequencies
#
# colenrfeb15
# 1. Not enrolled        6915
# 2. 2-year college       193
# 3. 4-year college       230
# 4. Graduate program     131
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb15
# 1. Not enrolled       0.93
# 2. 2-year college     0.03
# 3. 4-year college     0.03
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct15
#
# ----------------------
#
# frequencies
#
# colenroct15
# 1. Not enrolled        6905
# 2. 2-year college       189
# 3. 4-year college       249
# 4. Graduate program     126
# Name: count, dtype: int64
#
# percentages
#
# colenroct15
# 1. Not enrolled       0.92
# 2. 2-year college     0.03
# 3. 4-year college     0.03
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb16
#
# ----------------------
#
# frequencies
#
# colenrfeb16
# 1. Not enrolled        6567
# 2. 2-year college       156
# 3. 4-year college       199
# 4. Graduate program     114
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb16
# 1. Not enrolled       0.93
# 2. 2-year college     0.02
# 3. 4-year college     0.03
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct16
#
# ----------------------
#
# frequencies
#
# colenroct16
# 1. Not enrolled        6310
# 2. 2-year college       137
# 3. 4-year college       179
# 4. Graduate program     107
# Name: count, dtype: int64
#
# percentages
#
# colenroct16
# 1. Not enrolled       0.94
# 2. 2-year college     0.02
# 3. 4-year college     0.03
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenrfeb17
#
# ----------------------
#
# frequencies
#
# colenrfeb17
# 1. Not enrolled        6338
# 2. 2-year college       128
# 3. 4-year college       161
# 4. Graduate program     106
# Name: count, dtype: int64
#
# percentages
#
# colenrfeb17
# 1. Not enrolled       0.94
# 2. 2-year college     0.02
# 3. 4-year college     0.02
# 4. Graduate program   0.02
# Name: proportion, dtype: float64
#
#
# colenroct17
#
# ----------------------
#
# frequencies
#
# colenroct17
# 1. Not enrolled        6348
# 2. 2-year college       129
# 3. 4-year college       157
# 4. Graduate program     100
# Name: count, dtype: int64
#
# percentages
#
# colenroct17
# 1. Not enrolled       0.94
# 2. 2-year college     0.02
# 3. 4-year college     0.02
# 4. Graduate program   0.01
# Name: proportion, dtype: float64

# %% [raw]
# TAREA Generar un resumén estadístico de la base que tiene variables continuas.

# %%
# importando otra base

covidtotals = pd.read_csv("data/covidtotals.csv",parse_dates=['lastdate'])
covidtotals.set_index("iso_code", inplace=True)

# %%
covidtotals.shape
# Out:
# (231, 16)

# %%
# Obtenga las estadísticas descriptivas de las columnas de totales COVID-19:
totvars = ['total_cases', 'total_deaths','total_cases_pm','total_deaths_pm']
covidtotals[totvars].describe()
# Out:
#         total_cases  total_deaths  total_cases_pm  total_deaths_pm
# count  2.310000e+02  2.310000e+02      231.000000       231.000000
# mean   3.351599e+06  3.021420e+04   206177.794623      1261.778390
# std    1.148321e+07  1.047789e+05   203858.096252      1314.981529
# min    4.000000e+00  0.000000e+00      354.487000         0.000000
# 25%    2.567150e+04  1.775000e+02    21821.863000       141.177000
# 50%    1.914960e+05  1.937000e+03   133946.251000       827.046000
# 75%    1.294286e+06  1.415000e+04   345689.831000      1997.513000
# max    1.034368e+08  1.127152e+06   763475.441000      6507.656000

# %%
covidtotals[totvars].quantile(np.arange(0.0,1.1,0.1))
# Out:
#      total_cases  total_deaths  total_cases_pm  total_deaths_pm
# 0.0          4.0           0.0         354.487            0.000
# 0.1       8359.0          31.0        3138.575           32.885
# 0.2      17181.0         126.0       10885.737          105.298
# 0.3      38008.0         294.0       35834.604          210.509
# 0.4      74129.0         844.0       86126.235          498.789
# 0.5     191496.0        1937.0      133946.251          827.046
# 0.6     472755.0        4384.0      220429.369         1251.299
# 0.7    1041111.0        9646.0      293737.443         1697.571
# 0.8    1877065.0       21218.0      416608.106         2271.676
# 0.9    5641992.0       62288.0      512388.401         3155.939
# 1.0  103436829.0     1127152.0      763475.441         6507.656

# %% [raw]
# # FIN de la Tarea

# %% [raw]
# #########################################################################################################

# %% [raw]
# -Identificación y corrección de valores omitidos (así como valores omitidos lógicos)
# -Limpieza de valores perdidos

# %%
covidtotals = pd.read_csv("data/covidtotalswithmissings.csv",low_memory=False)
covidtotals.set_index("iso_code", inplace=True)

# %%
#covidtotals.shape
covidtotals
# Out:
#             lastdate           location  total_cases  total_deaths  \
# iso_code
# AFG         2/4/2024        Afghanistan       231539          7982
# ALB        1/28/2024            Albania       334863          3605
# DZA        12/3/2023            Algeria       272010          6881
# ASM        9/17/2023     American Samoa         8359            34
# AND         5/7/2023            Andorra        48015           159
# ...              ...                ...          ...           ...
# VNM       10/22/2023            Vietnam     11624000         43206
# WLF         6/4/2023  Wallis and Futuna         3550             8
# YEM        11/6/2022              Yemen        11945          2159
# ZMB        12/3/2023             Zambia       349304          4069
# ZWE        1/28/2024           Zimbabwe       266265          5737
#
#           total_cases_pm  ...  vac_per_hund  aged_65_older  life_expectancy  \
# iso_code                  ...
# AFG             5,629.61  ...           NaN           2.58            64.83
# ALB           117,813.35  ...           NaN          13.19            78.57
# DZA             6,057.69  ...           NaN           6.21            76.88
# ASM           188,712.04  ...           NaN            NaN            73.74
# AND           601,367.68  ...           NaN            NaN            83.73
# ...                  ...  ...           ...            ...              ...
# VNM           118,386.52  ...           NaN           7.15            75.40
# WLF           306,140.05  ...           NaN            NaN            79.94
# YEM               354.49  ...           NaN           2.92            66.12
# ZMB            17,449.78  ...           NaN           2.48            63.89
# ZWE            16,314.72  ...           NaN           2.82            61.49
#
#           hum_dev_ind           region
# iso_code
# AFG              0.51       South Asia
# ALB              0.80   Eastern Europe
# DZA              0.75     North Africa
# ASM               NaN    Oceania / Aus
# AND              0.87   Western Europe
# ...               ...              ...
# VNM              0.70        East Asia
# WLF               NaN    Oceania / Aus
# YEM              0.47        West Asia
# ZMB              0.58  Southern Africa
# ZWE              0.57  Southern Africa
#
# [231 rows x 16 columns]

# %%
# Empecemos por un análisis de los datos perdidos
demovars = ['pop_density','aged_65_older','gdp_per_capita','life_expectancy','hum_dev_ind']

# %%
# Aquí se especifica cuántos datos perdidos se tienen por columna
covidtotals[demovars].isnull().sum(axis=0)
# Out:
# pop_density        22
# aged_65_older      43
# gdp_per_capita     40
# life_expectancy     4
# hum_dev_ind        44
# dtype: int64

# %%
# Si se quiere el numero faltante de datos por fila,se usa:
demovarsmisscnt = covidtotals[demovars]
demovarsmisscnt
# Out:
#           pop_density  aged_65_older  gdp_per_capita  life_expectancy  \
# iso_code
# AFG             54.42           2.58        1,803.99            64.83
# ALB            104.87          13.19       11,803.43            78.57
# DZA             17.35           6.21       13,913.84            76.88
# ASM            278.20            NaN             NaN            73.74
# AND            163.75            NaN             NaN            83.73
# ...               ...            ...             ...              ...
# VNM            308.13           7.15        6,171.88            75.40
# WLF               NaN            NaN             NaN            79.94
# YEM             53.51           2.92        1,479.15            66.12
# ZMB             23.00           2.48        3,689.25            63.89
# ZWE             42.73           2.82        1,899.78            61.49
#
#           hum_dev_ind
# iso_code
# AFG              0.51
# ALB              0.80
# DZA              0.75
# ASM               NaN
# AND              0.87
# ...               ...
# VNM              0.70
# WLF               NaN
# YEM              0.47
# ZMB              0.58
# ZWE              0.57
#
# [231 rows x 5 columns]

# %%
demovarsmisscnt = covidtotals[demovars].isnull().sum(axis=1)
demovarsmisscnt
# Out:
# iso_code
# AFG    0
# ALB    0
# DZA    0
# ASM    3
# AND    2
#       ..
# VNM    0
# WLF    4
# YEM    0
# ZMB    0
# ZWE    0
# Length: 231, dtype: int64

# %%
# Aquí le decimos cuántos datos perdidos hay por filas. Por ejemplo sin datos perdidos hay 178 filas
demovarsmisscnt.value_counts().sort_index()
# Out:
# 0    178
# 4     16
# 2     14
# 3     11
# 1      8
# 5      4
# Name: count, dtype: int64

# %%
# Veamos algunos de los países con 4 o más valores omitidos.
covidtotals.loc[demovarsmisscnt>=4, ['location'] + demovars].sample(5, random_state=1).T
# Out:
# iso_code                      FLK                        SPM       GGY  \
# location         Falkland Islands  Saint Pierre and Miquelon  Guernsey
# pop_density                   NaN                        NaN       NaN
# aged_65_older                 NaN                        NaN       NaN
# gdp_per_capita                NaN                        NaN       NaN
# life_expectancy             81.44                      81.07       NaN
# hum_dev_ind                   NaN                        NaN       NaN
#
# iso_code                MSR           COK
# location         Montserrat  Cook Islands
# pop_density             NaN           NaN
# aged_65_older           NaN           NaN
# gdp_per_capita          NaN           NaN
# life_expectancy       74.16         76.25
# hum_dev_ind             NaN           NaN

# %% [raw]
# TIPS: si se quiere saber cuantos valores son únicos en una columna: nls97.birthyear.unique()

# %% [raw]
# TIPS: si se quiere saber cuantos valores están entre dos valores:
# nls97.loc[nls97["highestgradecompleted"].between(7,9),'highestgradecompleted'].value_counts()

# %% [raw]
# VAMOS a limpiar valores perdidos

# %%
schoolrecordlist = ['satverbal','satmath','gpaoverall','gpaenglish','gpamath','gpascience','highestdegree',
'highestgradecompleted']
schoolrecord = nls97[schoolrecordlist].copy()

# %%
schoolrecord.shape
# Out:
# (8984, 8)

# %%
schoolrecord
# Out:
#           satverbal  satmath  gpaoverall  gpaenglish  gpamath  gpascience  \
# personid
# 100061          NaN      NaN      306.00      350.00   280.00      315.00
# 100139          NaN      NaN         NaN         NaN      NaN         NaN
# 100284          NaN      NaN         NaN         NaN      NaN         NaN
# 100292          NaN      NaN      345.00      345.00   370.00      300.00
# 100583          NaN      NaN      291.00      283.00   285.00      240.00
# ...             ...      ...         ...         ...      ...         ...
# 999291       440.00   350.00      311.00      323.00   280.00      305.00
# 999406       460.00   440.00      217.00      280.00   114.00      143.00
# 999543          NaN      NaN         NaN         NaN      NaN         NaN
# 999698          NaN      NaN         NaN         NaN      NaN         NaN
# 999963       460.00   660.00      378.00      382.00   343.00      333.00
#
#            highestdegree  highestgradecompleted
# personid
# 100061    2. High School                  13.00
# 100139    2. High School                  12.00
# 100284           0. None                   7.00
# 100292      4. Bachelors                    NaN
# 100583    2. High School                  13.00
# ...                  ...                    ...
# 999291      4. Bachelors                  16.00
# 999406    2. High School                  14.00
# 999543    2. High School                  12.00
# 999698    2. High School                  12.00
# 999963      4. Bachelors                  17.00
#
# [8984 rows x 8 columns]

# %%
# schoolrecord.isnull().sum(axis=0) gives us the number of missing values for each column.

# %%
schoolrecord.isnull().sum(axis=0)
# Out:
# satverbal                7578
# satmath                  7577
# gpaoverall               2980
# gpaenglish               3186
# gpamath                  3218
# gpascience               3300
# highestdegree              31
# highestgradecompleted    2321
# dtype: int64

# %%
# We can create a Series, misscnt, with the number of missing variables for each observation
# with misscnt = schoolrecord.isnull().sum(axis=1).
misscnt = schoolrecord.isnull().sum(axis=1)
misscnt
# Out:
# personid
# 100061    2
# 100139    6
# 100284    6
# 100292    3
# 100583    2
#          ..
# 999291    0
# 999406    0
# 999543    6
# 999698    6
# 999963    0
# Length: 8984, dtype: int64

# %%
misscnt.value_counts().sort_index()
# Out:
# 0    1087
# 1     312
# 2    3210
# 3    1102
# 4     176
# 5     101
# 6    2039
# 7     946
# 8      11
# Name: count, dtype: int64

# %%
# In the following code we also take a look at a few observations with 7 or more missing values.
schoolrecord.loc[misscnt>=7]
# Out:
#           satverbal  satmath  gpaoverall  gpaenglish  gpamath  gpascience  \
# personid
# 101705          NaN      NaN         NaN         NaN      NaN         NaN
# 102061          NaN      NaN         NaN         NaN      NaN         NaN
# 102648          NaN      NaN         NaN         NaN      NaN         NaN
# 104627          NaN      NaN         NaN         NaN      NaN         NaN
# 104636          NaN      NaN         NaN         NaN      NaN         NaN
# ...             ...      ...         ...         ...      ...         ...
# 994992          NaN      NaN         NaN         NaN      NaN         NaN
# 997558          NaN      NaN         NaN         NaN      NaN         NaN
# 998103          NaN      NaN         NaN         NaN      NaN         NaN
# 998388          NaN      NaN         NaN         NaN      NaN         NaN
# 999053          NaN      NaN         NaN         NaN      NaN         NaN
#
#            highestdegree  highestgradecompleted
# personid
# 101705            1. GED                    NaN
# 102061           0. None                    NaN
# 102648            1. GED                    NaN
# 104627           0. None                    NaN
# 104636           0. None                    NaN
# ...                  ...                    ...
# 994992      4. Bachelors                    NaN
# 997558    2. High School                    NaN
# 998103           0. None                    NaN
# 998388    2. High School                    NaN
# 999053           0. None                    NaN
#
# [957 rows x 8 columns]

# %%
# Comprobamos que efectivamente se tiene 946 + 11 filas con más de 7 datos perdidos
schoolrecord.loc[misscnt>=7].shape
# Out:
# (957, 8)

# %%
schoolrecord.loc[misscnt>=7].head(4).T
# Out:
# personid               101705   102061  102648   104627
# satverbal                 NaN      NaN     NaN      NaN
# satmath                   NaN      NaN     NaN      NaN
# gpaoverall                NaN      NaN     NaN      NaN
# gpaenglish                NaN      NaN     NaN      NaN
# gpamath                   NaN      NaN     NaN      NaN
# gpascience                NaN      NaN     NaN      NaN
# highestdegree          1. GED  0. None  1. GED  0. None
# highestgradecompleted     NaN      NaN     NaN      NaN

# %%
# Vamos a descartar las observaciones que tienen valores perdidos en 7 o más variables,
# de un total de 8. Para ello, podemos lograr esto estableciendo el parámetro umbral
# de dropna en 2. Esto mantendrá las filas con al menos 2 non-NaN valores
schoolrecord = schoolrecord.dropna(thresh=2)
schoolrecord.shape
# Out:
# (8027, 8)

# %% [raw]
# Faltan bastantes valores para gpaoverall, 2.980, aunque tenemos valores válidos para dos tercios de las observaciones ((8984-2980)/8984). Podríamos salvarla como variable si realizamos un buen trabajo de imputación de los valores que faltan. Esto es probablemente más deseable que simplemente eliminar estas observaciones. No queremos perder esos datos si podemos evitarlo, sobre todo si los individuos con un gpaoverall que falta son diferentes de los demás en formas que serán importantes para nuestras predicciones.

# %% [raw]
# Lo más sencillo es asignar la media global de gpaoverall a los valores que faltan. El siguiente código utiliza el método pandas Series fillna para asignar todos los valores perdidos de gpaoverall al valor medio de la serie. El primer argumento de fillna es el valor que queremos para todos los valores perdidos, en este caso, schoolrecord.gpaoverall.mean(). Tenga en cuenta que debemos recordar establecer el parámetro inplace en True para sobrescribir realmente los valores existentes:

# %%
# DataFrame.agg(func=None, axis=0, *args, **kwargs)[source]
# Aggregate using one or more operations over the specified axis. df.agg({'A' : ['sum', 'min'], 'B' : ['min', 'max']})
# Lo primero es calcular la media, la desviación estandar y el número de datos. Con estos valores vamos a hacer la imputación.
schoolrecord.gpaoverall.agg(['mean','std','count'])
# Out:
# mean      281.84
# std        53.30
# count   8,027.00
# Name: gpaoverall, dtype: float64

# %%
# Rellenando valores faltantes con la media
schoolrecord.fillna({"gpaoverall":schoolrecord.gpaoverall.mean()}, inplace=True)
# Out:
# /tmp/ipykernel_4801/986199375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schoolrecord.fillna({"gpaoverall":schoolrecord.gpaoverall.mean()}, inplace=True)

# %%
schoolrecord.gpaoverall.isnull().sum()
# Out:
# np.int64(0)

# %%
# Aquí nos damos cuenta que estos valores no cambian en las columnas despúes de la imputación.
schoolrecord.gpaoverall.agg(['mean','std','count'])
# Out:
# mean      281.84
# std        53.30
# count   8,027.00
# Name: gpaoverall, dtype: float64

# %% [raw]
# En lugar de asignar el valor medio de los ingresos salariales a los valores que faltan, podríamos utilizar otra técnica habitual para imputar valores. Podríamos asignar el valor no faltante más cercano de una observación precedente.

# %%
wageincome20 = nls97.wageincome.copy(deep=True)

# %%
wageincome20
# Out:
# personid
# 100061    12,500.00
# 100139   120,000.00
# 100284    58,000.00
# 100292          NaN
# 100583    30,000.00
#             ...
# 999291    35,000.00
# 999406   116,000.00
# 999543          NaN
# 999698          NaN
# 999963    50,000.00
# Name: wageincome, Length: 8984, dtype: float64

# %%
wageincome20.isnull().sum()
# Out:
# np.int64(3893)

# %%
wageincome20.ffill(inplace=True)

# %%
wageincome20.isnull().sum()
# Out:
# np.int64(0)

# %% [raw]
# Podríamos haber hecho un relleno hacia atrás utilizando el método bfill. Esto establece los valores que faltan al valor siguiente más cercano. Esto produce lo siguiente:

# %% [raw]
# wageincome20 = nls97.wageincome.copy(deep=True)

# %%
wageincome20.iloc[0:10]
# Out:
# personid
# 100061    12,500.00
# 100139   120,000.00
# 100284    58,000.00
# 100292    58,000.00
# 100583    30,000.00
# 100833    39,000.00
# 100931    56,000.00
# 101089    36,000.00
# 101122    36,000.00
# 101132         0.00
# Name: wageincome, dtype: float64

# %%
wageincome20.bfill(inplace=True)

# %%
wageincome20.iloc[0:10]
# Out:
# personid
# 100061    12,500.00
# 100139   120,000.00
# 100284    58,000.00
# 100292    58,000.00
# 100583    30,000.00
# 100833    39,000.00
# 100931    56,000.00
# 101089    36,000.00
# 101122    36,000.00
# 101132         0.00
# Name: wageincome, dtype: float64

# %% [raw]
# En el NLS DataFrame, las semanas trabajadas en 2020 están correlacionadas con la titulación más alta obtenida. El siguiente código muestra cómo cambia el valor medio de las semanas trabajadas en función de la titulación obtenida. La media de semanas trabajadas es 38, pero es mucho más baja para los que no tienen titulación (28) y mucho más alta para los que tienen un título profesional (48). En este caso, puede ser una mejor opción asignar 28 a los valores que faltan para las semanas trabajadas de los individuos que no han obtenido un título, en lugar de 38.

# %%
nls97.groupby(['highestdegree'])['weeksworked17'].mean()
# Out:
# /tmp/ipykernel_4801/4234243946.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   nls97.groupby(['highestdegree'])['weeksworked17'].mean()
# highestdegree
# 0. None           28.72
# 1. GED            34.59
# 2. High School    38.15
# 3. Associates     40.44
# 4. Bachelors      43.57
# 5. Masters        45.14
# 6. PhD            44.31
# 7. Professional   47.20
# Name: weeksworked17, dtype: float64

# %% [raw]
# El siguiente código asigna el valor medio de las semanas trabajadas entre las observaciones con el mismo nivel de titulación para aquellas observaciones a las que les faltan semanas trabajadas. Para ello, se utiliza groupby para crear un DataFrame groupby, groupby([“highestdegree”])[“weeksworked20”]. A continuación, utilizamos "fillna" dentro de "transform" para rellenar los valores que faltan con la media del grupo de mayor titulación. Tenga en cuenta que nos aseguramos de hacer esta imputación sólo para las observaciones en las que no falta la información del grado más alto, nls97.highestdegree.notnull(). Seguiremos teniendo valores perdidos para las observaciones en las que falten tanto el título más alto como las semanas trabajadas.

# %%
nls97.loc[nls97.highestdegree.notnull(), 'weeksworked17']
# Out:
# personid
# 100061   48.00
# 100139   52.00
# 100284    0.00
# 100292     NaN
# 100583   52.00
#           ...
# 999291   52.00
# 999406   52.00
# 999543   30.00
# 999698    0.00
# 999963   52.00
# Name: weeksworked17, Length: 8953, dtype: float64

# %%
nls97.loc[nls97.highestdegree.notnull()].groupby(['highestdegree'])['weeksworked17'].transform(lambda x: x.fillna(x.mean()))
# Out:
# /tmp/ipykernel_4801/3349129933.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   nls97.loc[nls97.highestdegree.notnull()].groupby(['highestdegree'])['weeksworked17'].transform(lambda x: x.fillna(x.mean()))
# personid
# 100061   48.00
# 100139   52.00
# 100284    0.00
# 100292   43.57
# 100583   52.00
#           ...
# 999291   52.00
# 999406   52.00
# 999543   30.00
# 999698    0.00
# 999963   52.00
# Name: weeksworked17, Length: 8953, dtype: float64

# %%
nls97.loc[nls97.highestdegree.notnull(), 'weeksworked20imp'] = \
nls97.loc[nls97.highestdegree.notnull()].\
groupby(['highestdegree'])['weeksworked17'].\
transform(lambda x: x.fillna(x.mean()))
# Out:
# /tmp/ipykernel_4801/2196173779.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groupby(['highestdegree'])['weeksworked17'].\

# %%
nls97[["highestdegree","weeksworked17","weeksworked20imp"]].iloc[0:10]
# Out:
#            highestdegree  weeksworked17  weeksworked20imp
# personid
# 100061    2. High School          48.00             48.00
# 100139    2. High School          52.00             52.00
# 100284           0. None           0.00              0.00
# 100292      4. Bachelors            NaN             43.57
# 100583    2. High School          52.00             52.00
# 100833    2. High School          47.00             47.00
# 100931     3. Associates          52.00             52.00
# 101089    2. High School          52.00             52.00
# 101122    2. High School            NaN             38.15
# 101132           0. None          44.00             44.00

# %% [raw]
# #########################################################################################################

# %%
### Valores atípicos

# %% [raw]
# •Using histograms to examine the distribution of continuous variables
# •Using boxplots to identify outliers for continuous variables
# •Using grouped boxplots to uncover unexpected values in a particular group
# •Examining both distribution shape and outliers with violin plots
# •Using scatter plots to view bivariate relationships
# •Using line plots to examine trends in continuous variables

# %%
# Using histograms to examine the distribution of continuous variables

# %%
landtemps = pd.read_csv("data/landtemps2023avgs.csv")
covidtotals = pd.read_csv("data/covidtotals.csv", parse_dates=["lastdate"])
covidtotals.set_index("iso_code", inplace=True)

# %%
landtemps.iloc[0:10]
# Out:
#     locationid             station countryid               country  latabs  \
# 0  AE000041196  SHARJAH_INTER_AIRP        AE  United Arab Emirates   25.33
# 1  AEM00041194          DUBAI_INTL        AE  United Arab Emirates   25.25
# 2  AEM00041217      ABU_DHABI_INTL        AE  United Arab Emirates   24.43
# 3  AEM00041218         AL_AIN_INTL        AE  United Arab Emirates   24.26
# 4  AG000060390  ALGER_DAR_EL_BEIDA        AG               Algeria   36.72
# 5  AG000060590            EL_GOLEA        AG               Algeria   30.57
# 6  AG000060611           IN_AMENAS        AG               Algeria   28.05
# 7  AG000060680         TAMANRASSET        AG               Algeria   22.80
# 8  AGE00147708          TIZI_OUZOU        AG               Algeria   36.72
# 9  AGE00147716   NEMOURS_GHAZAOUET        AG               Algeria   35.10
#
#    elevation  avgtemp
# 0      34.00    28.84
# 1      10.40    30.05
# 2      26.80    26.27
# 3     264.90    29.56
# 4      24.00    19.21
# 5     397.00    23.31
# 6     561.00    23.02
# 7   1,362.00    23.28
# 8     222.00    20.43
# 9      83.00    19.57

# %%
# Show some of the station temperature rows.

# %%
landtemps[['station','country','latabs','elevation','avgtemp']].sample(10, random_state=1)
# Out:
#                         station        country  latabs  elevation  avgtemp
# 11924         WOLF_POINT_29_ENE  United States   48.31     635.50     5.90
# 10671             LITTLE_GRASSY  United States   37.48   1,859.30    10.19
# 10278  FLOWERY_TRAIL_WASHINGTON  United States   48.30     792.50     8.18
# 8436                ROCKSPRINGS  United States   30.02     726.00    20.31
# 1715               PETERBOROUGH         Canada   44.23     191.00     7.70
# 5650          TRACY_PUMPING_PLT  United States   37.80      18.60    17.64
# 335              NEPTUNE_ISLAND      Australia   35.34      32.00    16.47
# 372                     EUDUNDA      Australia   34.18     415.00    15.56
# 2987                  KOZHIKODE          India   11.25       5.00    29.57
# 7588                      TRYON  United States   35.21     365.80    16.12

# %%
landtemps.avgtemp.skew()
# Out:
# np.float64(-0.3856060165979757)

# %%
plt.hist(landtemps.avgtemp)
plt.axvline(landtemps.avgtemp.mean(), color='red', linestyle='dashed',linewidth=1)
plt.title("Histogram of Average Temperatures (Celsius)")
plt.xlabel("Average Temperature")
plt.ylabel("Frequency")
plt.show()

# %%
sm.qqplot(landtemps[['avgtemp']].sort_values(['avgtemp']), line='s')
plt.title("QQ Plot of Average Temperatures")
plt.show()

# %%
nls97 = pd.read_csv("data/nls97f.csv", low_memory=False)
nls97.set_index("personid", inplace=True)

# %%
plt.boxplot(nls97.satverbal.dropna(), labels=['SAT Verbal'])
plt.annotate('outlier threshold', xy=(1.05,780), xytext=(1.15,780),
size=7, arrowprops=dict(facecolor='black', headwidth=2, width=0.5,
shrink=0.02))
plt.annotate('3rd quartile', xy=(1.08,570), xytext=(1.15,570), size=7,
arrowprops=dict(facecolor='black', headwidth=2, width=0.5, shrink=0.02))
plt.annotate('median', xy=(1.08,500), xytext=(1.15,500), size=7,
arrowprops=dict(facecolor='black', headwidth=2, width=0.5, shrink=0.02))
plt.annotate('1st quartile', xy=(1.08,430), xytext=(1.15,430), size=7,
arrowprops=dict(facecolor='black', headwidth=2, width=0.5, shrink=0.02))
plt.annotate('outlier threshold', xy=(1.05,220), xytext=(1.15,220),
size=7, arrowprops=dict(facecolor='black', headwidth=2, width=0.5,
shrink=0.02))
plt.title("Boxplot of SAT Verbal Score")
plt.show()
# Out:
# /tmp/ipykernel_4801/3176534938.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(nls97.satverbal.dropna(), labels=['SAT Verbal'])

# %%
def gettots(x):
    out = {}
    out['min'] = x.min()
    out['qr1'] = x.quantile(0.25)
    out['med'] = x.median()
    out['qr3'] = x.quantile(0.75)
    out['max'] = x.max()
    out['count'] = x.count()
    return pd.Series(out)

# %%
nls97.groupby(['highestdegree'])['weeksworked21'].apply(gettots).unstack()
# Out:
#                  min   qr1   med   qr3   max    count
# highestdegree
# 0. None         0.00  0.00 39.00 49.00 52.00   487.00
# 1. GED          0.00  7.00 42.00 50.00 52.00   853.00
# 2. High School  0.00 27.00 42.00 50.00 52.00 2,529.00
# 3. Associates   0.00 38.00 43.00 49.00 52.00   614.00
# 4. Bachelors    0.00 40.00 43.00 50.00 52.00 1,344.00
# 5. Masters      0.00 41.00 45.00 52.00 52.00   614.00
# 6. PhD          0.00 41.00 44.00 49.00 52.00    59.00
# 7. Professional 0.00 41.00 45.00 51.00 52.00   105.00

# %%
# Haz un boxplot de las semanas trabajadas según el título más alto obtenido.

# %%
myplt = sns.boxplot(x='highestdegree',y='weeksworked21',data=nls97,order=sorted(nls97.highestdegree.dropna().unique()))
myplt.set_title("Boxplots of Weeks Worked by Highest Degree")
myplt.set_xlabel('Highest Degree Attained')
myplt.set_ylabel('Weeks Worked 2021')
myplt.set_xticklabels(myplt.get_xticklabels(), rotation=60,
horizontalalignment='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4801/1763431520.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   myplt.set_xticklabels(myplt.get_xticklabels(), rotation=60,
